# %% [markdown]
# <!-- <hr style="border:2px solid #C9CAE1"> -->
# <!-- <hr style="height: 2px; border: none; background-color: #DFDFEA;"> -->
#
# <!-- **<a id="1a" style="color:grey;">Color Scheme:</a>** -->
# <div style="background-color:#9EC6E1">
# </div>
# <div style="background-color:#CAE0F4">
# </div>
# <div style="background-color:#E3D8E6">
# </div>
# <div style="background-color:#C9CAE1">
# </div>
# <div style="background-color:#DFDFEA">
# </div>

# %% [markdown]
# <div style="background-color:#CAE0F4">
#
# ###  **Content** </div>
#
# <ul style="font-family:'Times New Roman'; list-style-type:*;">
#   <li><a href="#Week01">
#       Week 1: Data handling and probability</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#Probdistribution" style="color: #5575a9">Probability Distribution</a></li>
#         <ul style="font-family:'Times New Roman'; list-style-type:-;">
#           <li><a href="#1a" style="color: #9bacc7">Binomial Distribution</a></li>
#           <li><a href="#1b" style="color: #9bacc7">Poisson distribution</a></li>
#           <li><a href="#1c" style="color: #9bacc7">Normal/Gaussian distribution</a></li>
#           <li><a href="#1d" style="color: #9bacc7">Chi-squared distribution</a></li>
#         </ul>
#         <li><a href="#MonteCarlo" style="color: #5575a9">Monte Carlo Method</a></li>
#         <li><a href="#AcceptReject" style="color: #5575a9">Accept-Reject Method</a></li>
#       </ul>
#   <li><a href="#Week02">
#       Week 2: Hypothesis Testing</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#ChiSquared" style="color: #5575a9">Chi-squared distribution</a></li>
#         <li><a href="#KStest" style="color: #5575a9">Kolmogorov-Smirnov tests</a></li>
#       </ul>
#   <li><a href="#Week03">
#       Week 3: Likelihoods</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#loglikelihoods" style="color: #5575a9">Log likelihoods</a></li>
#         <li><a href="#binnedlikelihoods" style="color: #5575a9">Binned likelihoods</a></li>
#         <li><a href="#LHR" style="color: #5575a9">Negative Log-likelihood ratio (LHR)</a></li>
#       </ul>
#   <li><a href="#Week04">
#       Week 4: Parameter Estimation and Fitting Data</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#iminuit" style="color: #5575a9">Curve fitting with iMinuit</a></li>
#         <li><a href="#unbinned" style="color: #5575a9">Unbinned maximum likelihood</a></li>
#         <li><a href="#binned" style="color: #5575a9">Binned likelihood</a></li>
#       </ul>
#   <li><a href="#Week05">
#       Week 5: First ML Model</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#kNN" style="color: #5575a9">k-Nearest Neighbours (k-NN)</a></li>
#         <li><a href="#svm" style="color: #5575a9">Support Vector Machine (SVM)</a></li>
#       </ul>
#
#   <li><a href="#Week06">
#       Week 6: Performance Metrics</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#perfmetrics" style="color: #5575a9">Performance metrics in classification</a></li>
#         <li><a href="#metricregression" style="color: #5575a9">Performance metrics in regression</a></li>
#         <li><a href="#binned" style="color: #5575a9">Binned likelihood</a></li>
#       </ul>
#
#   <li><a href="#Week07">
#       Week 7: Decision Trees</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#treeclass" style="color: #5575a9">Decision Trees for classification</a></li>
#         <li><a href="#treereg" style="color: #5575a9">Decision Trees for regression</a></li>
#         <li><a href="#ensemble" style="color: #5575a9">Ensemble Learning (code non-examinable)</a></li>
#         <li><a href="#forest" style="color: #5575a9">Random Forests</a></li>
#         <li><a href="#BDTs" style="color: #5575a9">Boosted Decision Trees (BDTs)</a></li>
#       </ul>
#   <li><a href="#Week09">
#       Week 9: Introduction to Neural Networks</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#pytorch" style="color: #5575a9">PyTorch</a></li>
#         <li><a href="#NNL" style="color: #5575a9">Neural Network Learning</a></li>
#         <ul style="font-family:'Times New Roman'; list-style-type:-;">
#           <li><a href="#understandnnl" style="color: #9bacc7">Understanding NNL</a></li>
#           <li><a href="#codennl" style="color: #9bacc7">Code for training NNL with PyTorch</a></li>
#         </ul>
#       </ul>
#   <li><a href="#Week10">
#       Week 10: Convolutional Neural Networks</a></li>
#       <ul style="font-family:'Times New Roman'; list-style-type:-;">
#         <li><a href="#pytorch10" style="color: #5575a9">PyTorch</a></li>
#         <li><a href="#MNISTexample" style="color: #5575a9">Multiclass Classification example</a></li>
#       </ul>
# </ul>

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week01" style="color:black;">Week 1: Data handling and probability</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# - **Querying** e.g.`display(df.query('Water > 100 and Age < 100'))`
# - **Grouping data** e.g. `means = df.groupby('Age')['Strength'].mean()` Group by age, find the mean of the strength for each age group
# - **Finding summary statistics** `df.describe()`
# - **Save to excel** `df.to_excel('')`
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="Probdistribution">Probability distributions</a></h2>

# %% [markdown]
# ### <h3><a id="1a" style="color:#5575a9; text-decoration: None">a. Binomial distribution</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# $f(k; n, p) = {n \choose k}p^k q^{n-k}$

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(1,2,figsize = (14,6), tight_layout=True)
axs[0].set_title('Probability distribution',fontsize = 20)
axs[0].set_xlabel('$k$',fontsize = 16)
axs[0].set_ylabel('$f(k;n,p)$',fontsize = 16)
axs[1].set_title('Cumulative distribution',fontsize = 20)
axs[1].set_xlabel('$k$',fontsize = 16)
axs[1].set_ylabel('$F(k;n,p)$',fontsize = 16)

k = np.arange(0,40)
n = 50
p = 0.4

axs[0].scatter(k, binom.pmf(k,n,p))
axs[1].scatter(k, binom.cdf(k,n,p))

mean = n*p
var = n*p*(1-p)
print(mean, var)
# Out:
# 20.0 12.0

# %% [markdown]
# ### <h3><a id="1b" style="color:#5575a9; text-decoration: None">b. Poisson distribution</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# $f(k; \lambda) = (\lambda^ke^{-\lambda}) / k!$

# %%
from scipy.stats import poisson

fig, axs = plt.subplots(1,2,figsize = (14,6), tight_layout=True)
axs[0].set_title('Probability distribution',fontsize = 20)
axs[0].set_xlabel('$k$',fontsize = 16)
axs[0].set_ylabel('$f(k;\lambda)$',fontsize = 16)
axs[1].set_title('Cumulative distribution',fontsize = 20)
axs[1].set_xlabel('$k$',fontsize = 16)
axs[1].set_ylabel('$F(k;\lambda)$',fontsize = 16)

k = np.arange(0,20)
lamb = 4.1

axs[0].scatter(k, poisson.pmf(k,lamb))
axs[1].scatter(k, poisson.cdf(k,lamb))

mean = lamb
var = lamb

# %% [markdown]
# ### <h3><a id="1c" style="color:#5575a9; text-decoration: None">c. Normal/gaussian distribution</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# $f(X; \mu, \sigma) = \frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{1}{2}\left(\frac{X - \mu}{\sigma}\right)^2}$

# %%
from scipy.stats import norm

fig, axs = plt.subplots(1,2,figsize = (14,6), tight_layout=True)
axs[0].set_xlabel('$X$',fontsize = 16)
axs[0].set_ylabel('$f(X; \mu, \sigma)$',fontsize = 16)
axs[0].set_title('Probability distribution',fontsize = 20)
axs[1].set_xlabel('$X$',fontsize = 16)
axs[1].set_ylabel('$F(X;\mu,\sigma)$',fontsize = 16)
axs[1].set_title('Cumulative distribution',fontsize = 20)

x = np.arange(-10,10,0.1)
mu = -2
sig = 0.5

axs[0].plot(x, norm.pdf(x,mu,sig))
axs[1].plot(x, norm.cdf(x,mu,sig))

# %% [markdown]
# ### <h3><a id="1d" style="color:#5575a9; text-decoration: None">d. Chi-squared distribution</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %%
from scipy.stats import chi2

fig, axs = plt.subplots(1,2,figsize = (14,6), tight_layout=True)
axs[0].set_xlabel('$X/N_\mathrm{dof}$',fontsize = 16)
axs[0].set_ylabel('$f(X; N_\mathrm{dof})$',fontsize = 16)
axs[0].set_title('Probability distribution',fontsize = 20)
axs[1].set_xlabel('$X/N_\mathrm{dof}$',fontsize = 16)
axs[1].set_ylabel('$F(X;N_\mathrm{dof})$',fontsize = 16)
axs[1].set_title('Cumulative distribution',fontsize = 20)

xr = np.arange(0.1,2.5,0.005)
ndof = 7

axs[0].plot(xr,chi2.pdf(xr*ndof,ndof)) 
axs[1].plot(xr,chi2.cdf(xr*ndof,ndof))

# %%
# Generate dataset from a given distribution.
observations = norm.rvs(loc=0, scale=1, size=100)

# %% [markdown]
# ## <h2><a id="MonteCarlo">Monte Carlo Methods</a></h2>

# %%
number_observations = 10000

def pdf(x):
    return None

def inv(u):
    return None

# For reproducibility, fix the seed for the random number generator
rng_seed = 0
rng = np.random.default_rng(rng_seed) # This is a random number generator (hence "rng") method
samples = rng.uniform(0,1,size = number_observations)
draws = inv(samples)

# plt.hist(draws, bins=50, density=True)
# plt.plot(np.linspace(-2, 2, 100), pdf(np.linspace(-2, 2, 100)), color='r')

# %%
from matplotlib.colors import to_rgba
from scipy.interpolate import CubicSpline
from matplotlib.ticker import LogLocator
from matplotlib.ticker import MultipleLocator
import numpy as np
import matplotlib.pyplot as plt

# Numerical inverse transform method
cf_iso = np.load('cf_spectra.npy',allow_pickle = True).item() 
X = cf_iso['X']
y = cf_iso['y']

# THIS CODE ONLY WORKS if the input data is sorted in order of X values
# with smallest X values first.
ycdf = y.cumsum()
ycdf = ycdf/ycdf[-1] # Normalise the cdf using the last value (=total)

# Interpolate the inverted function
inv = CubicSpline(ycdf, X)

fig, (ax0,ax1) = plt.subplots(2,1,figsize = (6,8),dpi = 150, tight_layout=True)
ax0.plot(ycdf,X,'x', label='Original data',color='black')
ax0.plot(ycdf,inv(ycdf),label='Interpolated data',ls='--',color='#D55E00')
ax0.set_xlabel('$u$',fontsize = 16)
ax0.set_ylabel('$F^{-1}(u)$',fontsize =16)
ax0.set_yscale('log')
ax0.legend()
ax0.set_title('Inverse cumulative distribution',fontsize = 20)


# Monte Carlo methods
u = np.random.default_rng().uniform(0,1,size = 100000)
samples = inv(u)

bins = np.logspace(-8,2,100)
ax1.hist(samples, bins = bins,color='#D55E00', label='Artificial data',)
ax1.set_xlabel('Energy [MeV]',fontsize = 16)
ax1.set_ylabel('Frequency',fontsize = 16)
ax1.set_xscale('log')
ax1.set_title('Generated distribution',fontsize = 20)
ax1.set_xlim(1e-8,56)
ax1.xaxis.set_major_locator(LogLocator(base = 10.0,numticks = 14))
ax1.xaxis.set_minor_locator(LogLocator(base = 10.0,numticks = 14, subs = [0.2,0.4,0.6,0.8]))
ax1.yaxis.set_minor_locator(MultipleLocator(400))

# %% [markdown]
# ## <h2><a id="AcceptReject">Accept-Reject Methods</a></h2>

# %%
def f(x):
    return -x**2 + 4 #Change this to your function - don't worry about normalisation

# We want to generate values within the range X=-2..2. 
# We need $a$ the maximum value of $f(X)$ in that range which we set by hand
a_value = f(0.0) #Change this

# For reproducibility, I like to fix the seed for the random number generator, any number is as good as any other
rng = np.random.default_rng(0) 

# Generate uniform X samples in the region of interest
min_x = -2 #Change this
max_x = 2 #Change this
x_samples = rng.uniform(min_x, max_x, size = 5000)

# Generate uniform y samples in U(0, max(f(X)) (where the max(f(X) here is at f(0))
y_samples = rng.uniform(0, a_value,size = 5000)
 
# Find which samples fulfill the criteria y <= f(X);
# This is an array of True and False values 
accept = (y_samples <= f(x_samples))

fig, ax = plt.subplots(1,1,figsize = (9,7), tight_layout=True)
ax.plot(np.linspace(min_x, max_x, 100),f(np.linspace(min_x, max_x, 100)),label='$f(X)$',color='black')
# Next plot ALL the points tried as failed points 
ax.scatter(x_samples, y_samples, s = 1, label='Rejected samples', color='#56B4E9')
# but then for the points we accept we plot another point to indicate accepted points as this will be on top and seen by us
ax.scatter(x_samples[accept],y_samples[accept],s = 1,c='#D55E00',label = 'Accepted samples')
ax.legend(fontsize = 12)

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week02" style="color:black;">Week 2: Hypothesis Testing</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
# **Type-I error rate:** $\alpha = \int_{\text{critical region}}f(X) \, dX$
#
# **Power of a hypothesis test:** $1-\beta = \int_{\text{critical region}}g(X) \, dX$
#
# **p-value**
#
# $p = P(t|H_0)=\int_t^\infty dt' \, p(t'|H_0)$
# - $p<\alpha$ Statistically significant - reject H_0
# - $p>\alpha$ Not significant - fail to reject

# %% [markdown]
# - `ppf(alpha)` returns the value of X that gives the cumulative probability `alpha` (returns the inverse of the CDF)
# - `.interval(1-alpha)` retusn the boundaries of that interval that contains $(1-\alpha)$ of the distribution: = `ppf([(1-alpha)/2, (1+alpha)/2])`
#     - works for any continuous (and many discrete) distributions in scipy.stats, not just norm. SciPy defines .interval(confidence) as the equal-tailed interval.

# %%
import numpy as np
import scipy

alpha = 0.05
interval = norm.interval(1 - alpha, loc = 0, scale = 1) # Standard normal distribution
print(interval)
# Out:
# (np.float64(-1.959963984540054), np.float64(1.959963984540054))

# %% [markdown]
# Optional: Use the *error function* from scipy to evaluate the integral of a Gaussian.

# %%
np.sqrt(2)*scipy.special.erfinv(0.95)
# Out:
# np.float64(1.9599639845400538)

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="ChiSquared">Chi-squared distribution</a></h2>

# %% [markdown]
# Assume that the datapoints $y_{i}$ is normally dsitributed from the model function as the mean value. A good fit is where $y_{i}$ differs from the mean model value in the order of $\sigma_{i}$. Therefore, for a good fit, the chi-squared value should be close to the number of datapoints (reduced-chi-squared close to 1).
#
# $\chi^2(y_i) = \sum_i p_i^2 = \sum_i \frac{(y_i - f(X_i))^2}{(\sigma_i)^2},
# $

# %% [markdown]
# Choose $\alpha$ (e.g. 5%), determine if we would reject $H_0$ using p-value:

# %%
from scipy.stats import chi2
chi2_value = 7
N_dof = 5

print("p-value:", chi2.sf(chi2_value, N_dof)) #func.sf()="Survival function"=(1 - func.cdf)
# Out:
# p-value: 0.22064030793671066

# %% [markdown]
# ## <h2><a id="KStest">Kolmogorov-Smirnov tests</a></h2>

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
# **Empirical cumulative distribution** $F_{\text{data}}(X) = \frac{\text{number of data values} < X}{n},$
#
# We can look at performing either a one-sided or a two-sided hypothesis test on the Kolmogorov-Smirnov statistic. These correlate to different null and alternate hypotheses:
#
# * Two-sided test: Null hypothesis is $F(X) = G(X)$; alternate hypothesis is $F(X) \neq G(X)$
# <br>
#
# * One-sided test: there are two possible tests:
#     1. $H_0: F(X) \geq G(X)\, \forall \, X$; $H_1: F(X) \lt G(X)$ for at least one value of $X$
#     1. $H_0: F(X) \leq G(X)$ \, \forall \, $X$; $H_1: F(X) \gt G(X)$ for at least one value of $X$
#
# - One-sided test: `scipy.stats.ksone`
# - Two-sided test: `scipy.stats.kstwo`

# %%
np.random.seed(0) 
number_data = 50
samples = norm.rvs(loc=0.0, scale=1.0, size = number_data)
Xmin=-3.0
Xmax=3.0
Xvalues = np.linspace(Xmin, Xmax, number_data*2) 

def Fd(X):
    """ This gives the empirical cumulative distribution of the data in "samples" for given X value """
    return np.count_nonzero(samples<X)/len(samples)

empirical = [Fd(X) for X in Xvalues] # For visualization

# %% [markdown]
# <a style="color:#5575a9;">**One sample KS test**</a>
#
# How likely is it that we would see these data samples if the data is drawn from that probability distribution? $D = \max_X |F_\text{data}(X) - G(X)|$. In general, larger D indicate worse agreement

# %%
# Calculate manually
from scipy.stats import kstwo
samples_cumulative = [Fd(X) for X in samples] # For data evaluation
D = np.max(np.abs(samples_cumulative - norm.cdf(samples)))
p_value = kstwo.sf(D,len(samples))
print(D, p_value)

# ks_1samp
from scipy.stats import ks_1samp
d1_D, d1_p = ks_1samp(samples, norm.cdf)   # Only need to input the sample.
#D_norm, p_norm = ks_1samp(sample, norm.cdf, norm_arg) for non-standard normal distribution, need to input the distribution parameters as well.
print(d1_D, d1_p)

#kstest
from scipy.stats import kstest
ks_result = kstest(samples, norm.cdf)
print("Now D = {:.3f}, p-value = {}".format(ks_result.statistic,ks_result.pvalue))
# Out:
# 0.10706475374815838 0.5781417630622738
# 0.10706475374815838 0.5781417630622738
# Now D = 0.107, p-value = 0.5781417630622738

# %% [markdown]
# <a style="color:#5575a9;">**Two sample KS test:**</a>
#
# How likely is it that we would see these two sets of data samples if they are drawn from the same (but unknown) probability distribution?
# $D_2 = \text{sup}_X|F_\text{data}(X) - G_\text{data}(X)|$

# %%
# ks_2samp
from scipy.stats import ks_2samp
samples_normal_1 = norm.rvs(size = number_data)
samples_normal_2 = norm.rvs(size = number_data)
d2_D, d2_p = ks_2samp(samples_normal_1, samples_normal_2)  
print(d2_D, d2_p)

#kstest
ks_result = kstest(samples_normal_1, samples_normal_2)
print("Now D = {:.3f}, p-value = {}".format(ks_result.statistic,ks_result.pvalue))
# Out:
# 0.22 0.17858668181221732
# Now D = 0.220, p-value = 0.17858668181221732

# %% [markdown]
# For discrete distribution, use the $\frac{\text{counts}}{\text{total counts}}$ for the probability.

# %%
#Example calculation of power of the K-S test from the distribution of D values under H0 and H1

critical_value = 0.1
print('Type-I error',
      np.count_nonzero(np.array(DvalsH0)>critical_value)/n_samples)
print('Type-II error',
      np.count_nonzero(np.array(DvalsH1)<critical_value)/n_samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 #Example calculation of power of the K-S test from the distribution of D values under H0 and H1
#       3 critical_value = 0.1
#       4 print('Type-I error',
# ----> 5       np.count_nonzero(np.array(DvalsH0)>critical_value)/n_samples)
#       6 print('Type-II error',
#       7       np.count_nonzero(np.array(DvalsH1)<critical_value)/n_samples)
#
# NameError: name 'DvalsH0' is not defined

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week03" style="color:black;">Week 3: Likelihoods</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# Likelihood: $P(X|H_{0})$:
#
# $$P(H_{0}|X) = P(X|H_{0})\dfrac{P(H_{0})}{P(X)}$$

# %% [markdown]
# ## <h2><a id="loglikelihoods">Log likelihoods</a></h2>

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
# $$
# \ln L(H) = \ln \prod_{i}^{N}f(X_{i}|H) = \sum_{i=1}^{N} \ln f(X_{i}|H)
# $$
#
# The *likelihood* for either discrete or continuous distribution is just the product of observing the outcome.

# %%
from scipy.stats import expon #exponential distribution

measurements = np.array([0.72863217, 0.30653282, 0.99725302, 1.95956204, 1.60472692, 0.48397563, 0.14558313, 4.60142088, 0.55139557, 1.30257874])

l_H = np.prod(expon.pdf(measurements))
print("Likelihood exponential distribution: {}".format(l_H))

log_l_H = np.sum(expon.logpdf(measurements))
print("log-Likelihood exponential distribution: {}".format(log_l_H))
# Out:
# Likelihood exponential distribution: 3.1075966247446967e-06
# log-Likelihood exponential distribution: -12.68166092

# %% [markdown]
# ## <h2><a id="binnedlikelihoods">Binned likelihoods</a></h2>

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
# A binned likelihood is simply a **product  of Poisson likelihoods** since the count in each bin is distributed as a Poisson random variable $\left( f(k, \lambda)=e^{-\lambda}\lambda^k / k! \right)$. If you have some probability  density function $f$, then the Poisson parameter $\lambda$ for the bin defined as the range $[x_{a},x_{b}]$ (bin-boundaries) is
# defined as:
#
# $$
#     \lambda = N\int_{x_{a}}^{x_{b}} f(x)dx
# $$

# %%
from scipy.stats import poisson

def PoissonLambda(a,b):
    # function to return the integral of the NORMAL distribution between a and b
    return len(observations)*(norm.sf(a) - norm.sf(b))

def Count(a,b,observations):
    # function to return the number of events between the range a and b
    return np.size(observations[(observations >= a) & (observations < b)])

bins = np.linspace(-5,5,num=10,endpoint=True)
intervals = [[bins[i],bins[i+1]] for i in range(len(bins)-1)]

# get the counts in data and integrals for each interval
counts = [Count(x[0],x[1],observations) for x in intervals]
lambdas = [PoissonLambda(x[0],x[1]) for x in intervals]

binned_ln_l = np.sum([poisson.logpmf(c,l) for c,l in zip(counts,lambdas)])   # <--- How likely you are to see bins with this count and lambda given by Poisson.

print("binned log-Likelihood normal distribution: {}".format(binned_ln_l))
# Out:
# binned log-Likelihood normal distribution: -13.745555020770496

# %% [markdown]
# ## <h2><a id="LHR">Negative Log-Likelihood Ratio (LHR)</a></h2>

# %% [markdown]
# <div style="background-color:#DFDFEA">
# The LHR is often calculated analytically (Neyman-Pearson lemma):
#
# $$
# -\ln(\Lambda) = -\ln \left(\dfrac{L(H_{1})}{L(H_0)}\right)  = \ln L(H_{0}) - \ln L(H_{1})
# $$
#
# </div>
#
# <div style="background-color:#e3d8e6">
#
# ***Side note*** (optional, but may be useful):
# $$
#     1-\beta  = \int_{c^{\prime}}f(X|H_{1})dX
#
#              = \int_{c^{\prime}}\Lambda f(X|H_{0})dX
#
#              =  E\left[\Lambda \right]_{c^{\prime}},
# $$
# We want to choose $c'$ that maximizes $\Lambda = \frac{f(X|H_{1})}{f(X|H_{0})}$

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd

fig, ax = plt.subplots(1,1,figsize = (6,5),dpi = 150)
df = pd.read_csv('data_1D.csv')

n_samples = 10000
nlogLambdaDistH0 = []
nlogLambdaDistH1 = []

for i in range(n_samples):
    rvsH0 = norm.rvs(0,1,size=len(df['data'])) # Generate data under H0
    rvsH1 = norm.rvs(1,1,size=len(df['data'])) # Generate data under H1

    nlogLambdaDistH0.append(sum(0.5-rvsH0)) # Value of -ln(Lambda) for this sample under H0
    nlogLambdaDistH1.append(sum(0.5-rvsH1)) # Value of -ln(Lambda) for this sample under H1

nlogLambda = sum(0.5-(df['data'])) # Value of -ln(Lambda) for the observed data

ax.hist(nlogLambdaDistH0, bins=30, color='blue', histtype='step', density=True,label="$H_{0}$")
ax.hist(nlogLambdaDistH1, bins=30, color='orange', histtype='step', density=True,label="$H_{1}$")

ax.axvline(nlogLambda,color='black',linestyle='--',label='Observed $-\\ln(\\Lambda)$')

ax.set_xlabel('$-\\ln(\\Lambda)$',fontsize = 12)
ax.set_ylabel('Probability Density',fontsize = 12)

ax.legend()

# %% [markdown]
# <!--
# <hr style="border:2px solid #DFDFEA"> -->
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# **<a style="color:#5575a9; text-decoration:none;">As classifiers:</a>**
#
# Vary $-\ln{\Lambda_{max}}$ that defines the upper bound of the critical region ($\alpha$ = area under $H_0$ to the left of $\ln{\Lambda_{max}}$, $1-\beta$ = area under $H_1$ to the left of $\ln{\Lambda_{max}}$)
# <!--
# <hr style="border:2px solid #DFDFEA"> -->
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %%
# Example
alpha = [len(nLogLH0[nLogLH0<lnLmax])/len(nLogLH0) for lnLmax in np.linspace(-5,20,100)]
power = [len(nLogLH1[nLogLH1<lnLmax])/len(nLogLH1) for lnLmax in np.linspace(-5,20,100)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Example
# ----> 2 alpha = [len(nLogLH0[nLogLH0<lnLmax])/len(nLogLH0) for lnLmax in np.linspace(-5,20,100)]
#       3 power = [len(nLogLH1[nLogLH1<lnLmax])/len(nLogLH1) for lnLmax in np.linspace(-5,20,100)]
#
# Cell In[22], line 2, in <listcomp>(.0)
#       1 # Example
# ----> 2 alpha = [len(nLogLH0[nLogLH0<lnLmax])/len(nLogLH0) for lnLmax in np.linspace(-5,20,100)]
#       3 power = [len(nLogLH1[nLogLH1<lnLmax])/len(nLogLH1) for lnLmax in np.linspace(-5,20,100)]
#
# NameError: name 'nLogLH0' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week04" style="color:black;">Week 4: Parameter Estimation and Fitting Data</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# Parameter estimations include **maximizing log-likelihood** $\color{#5575a9} \ln L(\theta; X_i) = \sum_{i = 1}^N\ln f(X_i;\theta)$ (which is found analytically as a function of the parameter) and **minimizing chi-squared** $\color{#5575a9} \left(\chi^2 = 2C - 2\ln(L) \right)$.

# %% [markdown]
# **Numerical optimisation of cost functions**
#
# Then you will use methods like gradient descent to find the optimal parameter value. Recall that ***gradient descent*** is used for minimisation problems (chi-squared and negative log likelihood). This can be implemented using iMinuit.
#
# <div style="background-color:#E3D8E6">
#
# 1. Define an initial parameter guess $\theta_{\text{init}}$ and set our parameter estimate $\hat{\theta}$ equal to it
# 1. Calculate (numerically) the gradient of the cost function $q$ evaluated at the initial guess, $\frac{\partial q}{\partial \hat{\theta}}$
# 1. Update the value of $\hat{\theta}$ according to
# \begin{equation*}
# \hat{\theta} = \hat{\theta} - \alpha \frac{\partial q}{\partial\hat{\theta}}
# \end{equation*}
# where $\alpha$ is a parameter known as the **learning rate**.
# 1. Repeat steps 2 and 3 until the value of the cost function is below some satisfactory value or satisfies some convergence condition

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# For **uncertainty $\Sigma$** in the parameter estimates, Taylor expand around the stationary point and rewrite the log-likehood or chi-squared in the form of a Gaussian log-likelihood or a chi-squared distribution. The term where the $\sigma$ is located will be taken as the error of the estimation.
#
# This means the uncertainty is the range that changes the log-likelihood by -1/2 (from **maximum**):
# $$\ln(L(\hat{\theta}\pm\Sigma)) = \ln(L(\hat{\theta})) - \frac{1}{2}$$
#
# whereas for the chi-squared we look for the range that changes by +1 (from **minimum**):
# $$\chi^2(\hat{\theta} \pm \Sigma) \approx \chi^2(\hat{\theta}) + 1$$
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="iminuit">Curve fitting with iMinuit</a></h2>

# %% [markdown]
# ### 1. Define a fit function

# %%
import iminuit
import numpy as np

def line(x, m, c):
    return x*m + c

#-------------------------------
def line_np(x, par): # Arbitrary order polynomial, par is a list of parameters
    """
    Returns par[0]*x**(N-1) + par[1]*x**(N-2) + ... + par[N-2]*x + par[N-1]
    """
    return np.polyval(par, x)  # for len(par) == 2, this is a line

m_value=1.0
c_value=2.0

n_points = 11 # 11 data points
data_x = np.linspace(0,1,n_points) # evenly spaced from 0.0 to 1.0 inclusive 
data_yerr = 0.1 # the standard deviation of the noise
data_y = line(data_x, m_value, c_value) + np.random.default_rng().normal(loc = 0, scale = data_yerr, size = n_points)

# %% [markdown]
# ### 2. Define a cost function

# %%
from iminuit.cost import LeastSquares 
least_squares_line = LeastSquares(data_x, data_y, data_yerr, line)
#-------------------------------
least_squares_np = LeastSquares(data_x, data_y, data_yerr, line_np)
# Cost function doesn't like any error = 0 so make sure any that would be 0 are altered.
print("Lowest count in any bin is "+str(min(data_y)))

# %%
#Mask
# The mask is just an array of boolean values, true at each X value (in data_x) to be included 
xsignal_min=120
xsignal_max=130

x_mask_no_signal = (data_x < xsignal_min) | (data_x >xsignal_max)
signal_lsq_eg_obj2.mask= x_mask_no_signal

# %% [markdown]
# ### 3. Create a Minuit object

# %%
from iminuit import Minuit 

# Starting parameter values often important but not in this simple case plus we can overried the naming convention.
mline = Minuit(least_squares_line, m = 5.5, c = 6.0)
display(mline.init_params)

#-------------------------------
m_cubic_obj = Minuit(least_squares_np, (5.5, 4.1, 6.9, 0.4), name=("a", "b", "c", "d"))
display (m_cubic_obj)
# Out:
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m    │   5.50    │   0.06    │            │            │         │         │       │
# │ 1 │ c    │   6.00    │   0.06    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │   5.50    │   0.06    │            │            │         │         │       │
# ...

# %% [markdown]
# ### 4. Define the optimization algorithm and error + advanced parameter methods

# %%
# Fix and set limits before running the optimizer
mline.fixed['m'] = False
mline.fixed['c'] = True
mline.fixed = False # Can release all parameters at once this way

mline.limits['m'] = (0,None) # set limit on m to be minimum of 0, no maximum
mline.limits['c'] = (-float("infinity"), 10) # set maximum value of c as 10, no minimum
mline.limits['m'] = (0,10) # set limit on m to be minium of 0, maximum of 10
mline.limits['m'] = (None, None)
mline.limits = [(0, None), (0,10)]


mmm = (mline.migrad())   # minimise the least_squares cost function, i.e. find the best fit
hhh = (mline.hesse())   # calculate parameter uncertainties
display(hhh)

#--------------------------
mmm3 = m_cubic_obj.migrad() 
hhh3 = m_cubic_obj.hesse()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 10.92 (χ²/ndof = 1.2)      │              Nfcn = 88               │
# │ EDM = 3.36e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ...

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
# `iminuit` has two different methods for calculating the uncertainty on parameter estimates:
# * **Hesse** numerically calculates the second derivative of the cost function with respect to the parameters to form a matrix then inverts it to find the error matrix (called the Hesse matrix)
#     - Correlation matrix: `mline.covariance.correlation()`
# * **Minos** examines the cost function near the minimum to find where the cost function changes by `errordef`, a value specific to the cost function (e.g. =1 for $\chi^2$ and =0.5 for $-\ln{L}$). This can give asymmetric errors.

# %% [markdown]
# ### 5. Display the results

# %%
display(mline.params)
print("_"*50)

display(*mline.values)   #<--- Use this to visualize the plot.
# plt.plot(np.linspace(0,1,100),line(np.linspace(0,1,100),*mline.values),color='black')
print("-"*50)

for param in mline.params:
    print('{} = {:.2f} +/- {:.2f}'.format(param.name, param.value, param.error))
# Have to come across the f strings in python?  A recent addition but you can live without it too.
print("."*50)

# Chi-squared value for fit.
print(f"Simple line fit has chi^2/dof = {mline.fval:.2f} / {mline.ndof:.0f} = {mline.fmin.reduced_chi2:.2f}")
print("_"*50)

for param in mline.init_params:
    print(repr(param))

print("."*50)
# print(repr(...)) to see a detailed representation of the data object
print(repr(mline.fmin))

Minuit.valid
# Out:
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m    │    1.0    │    0.1    │            │            │    0    │         │       │
# │ 1 │ c    │   1.99    │   0.06    │            │            │    0    │   10    │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# __________________________________________________
# 0.9980422550106633
# 1.9880660971288588
# --------------------------------------------------
# m = 1.00 +/- 0.10
# c = 1.99 +/- 0.06
# ..................................................
# Simple line fit has chi^2/dof = 10.92 / 9 = 1.21
# __________________________________________________
# ...

# %% [markdown]
# ### 6. Varying starting points:

# %%
# Starting value θ = -0.1
m2minima = Minuit(cost_function_with_two_minima, θ=-0.1)
m2minima.migrad()

# Now changing the starting value to 0.1 gives the right minimum
m2minima.values['θ'] = 0.1
m2minima.migrad()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Starting value θ = -0.1
# ----> 2 m2minima = Minuit(cost_function_with_two_minima, θ=-0.1)
#       3 m2minima.migrad()
#       5 # Now changing the starting value to 0.1 gives the right minimum
#
# NameError: name 'cost_function_with_two_minima' is not defined

# %% [markdown]
# ### 7. Profiles and Contours

# %%
m_h, Lm_h, _ = mline.mnprofile("m")

pts_1 = mline.mncontour("m","c",cl=0.683, size = 100)
pts_2 = mline.mncontour("m","c",cl=0.9,size = 100)
pts_3 = mline.mncontour("m","c",cl=0.95,size = 100)
fig, ax = plt.subplots(2,1,figsize = (5,8),dpi = 150)
ax[0].plot(m_h,Lm_h,color='#D55E00')
ax[0].set_xlabel('$m$', fontsize = 16)
ax[0].set_ylabel(r'$FCN(m)$',fontsize = 16)
ax[0].tick_params(direction='in',top=True,right=True,which='both',labelsize = 12)
ax[0].set_title('Cost function for $m$',fontsize = 20)

ax[1].plot(pts_1.T[0],pts_1.T[1],color='#D55E00',label = '68.3%')
ax[1].plot(pts_2.T[0],pts_2.T[1],color='#56B4E9',label = '90%')
ax[1].plot(pts_3.T[0],pts_3.T[1],color='#E69F00',label = '95%')
ax[1].set_xlabel('$m$',fontsize = 16)
ax[1].set_ylabel('$c$',fontsize = 16)
ax[1].tick_params(which='both',direction='in',top = True, right = True,labelsize = 12)
ax[1].legend(loc='upper right',fontsize = 12)
ax[1].set_title('Contour of uncertainty intervals \n for $m$ and $c$',fontsize = 20)

fig.tight_layout()

# %% [markdown]
# ## <h2><a id="unbinned">Unbinned maximum likelihood</a></h2>

# %% [markdown]
# Unbinned so you don't need to pass any information about the actual binning, just the samples to the cost function.
#
# \begin{equation*}
# f(X; z, \mu, \sigma) = zf_{\text{normal}}(X; \mu, \sigma) + (1 - z)f_{\text{uniform}}(X)
# \end{equation*}

# %%
from iminuit.cost import UnbinnedNLL

def model_pdf(x, z, mu, sigma):
    return (z*norm.pdf(x, mu, sigma) + (1-z)*uniform.pdf(x, xrange[0], xrange[1]-xrange[0]))

cost_function = UnbinnedNLL(x_data, model_pdf) # only need to pass the samples we have.

m_obj = Minuit(cost_function, z = 0.4, mu = 0, sigma = 0.2) # arbitrary starting parameters
m_obj.limits['z'] = (0,1) # Set limit on z

m_obj.migrad()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 6
#       3 def model_pdf(x, z, mu, sigma):
#       4     return (z*norm.pdf(x, mu, sigma) + (1-z)*uniform.pdf(x, xrange[0], xrange[1]-xrange[0]))
# ----> 6 cost_function = UnbinnedNLL(x_data, model_pdf) # only need to pass the samples we have.
#
# NameError: name 'x_data' is not defined

# %% [markdown]
# ## <h2><a id="binned">Binned likelihood</a></h2>

# %% [markdown]
# Approximating the predicted count in a bin:
#
# $$\color{#5575a9} n(b) \approx (X_b - X_{b-1}) \, f(\bar{X}_{b}; \theta) \, , \quad \text{where} \quad \bar{X}_b = (X_{b} + X_{b-1})/2 \, .$$
#
# The cost functions for binned fits that are implemented in Minuit assumes that the bin counts are independently Poisson distributed about some unkown expected value per bin. This is correct for ordinary histograms.
#
# For a given PDF $f(X; \boldsymbol{\theta})$ with parameters $\boldsymbol{\theta}$, we can write the expected count $\lambda_i$ in a given bin with boundaries $a_i$ and $b_i$ as
#
# \begin{equation*}
# \lambda_i = \int_a^bf(X;\boldsymbol{\theta}) dX
# \end{equation*}
#
# The cost function for a binned maximum-likelihood fit is the **sum of the logarithms of the Poisson probability for the count in each bin, as a function of the expected counts $\lambda_i$**. This is again multiplied by -1 to go from a maximisation problem to a minimisation problem. However, instead of supplying a PDF we must provide a **CDF** in this case. We can approximate the CDF as bin-width multiplied by the PDF evaluated at the bin center if it is difficult to calculate, but this is only an approximation. Using an exact CDF is better.

# %%
from iminuit.cost import BinnedNLL

def model_cdf(xe, z, mu, sigma):
    return (z * norm.cdf(xe, mu, sigma) +
            (1-z) * uniform.cdf(xe, xrange[0], xrange[1] - xrange[0]))

bnll_cost_function = BinnedNLL(counts, bin_edges, model_cdf)

bnll_mobj = Minuit(bnll_cost_function, z = 0.4, mu = 0, sigma = 0.2)
bnll_mobj.migrad()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 7
#       3 def model_cdf(xe, z, mu, sigma):
#       4     return (z * norm.cdf(xe, mu, sigma) +
#       5             (1-z) * uniform.cdf(xe, xrange[0], xrange[1] - xrange[0]))
# ----> 7 bnll_cost_function = BinnedNLL(counts, bin_edges, model_cdf)
#
# NameError: name 'counts' is not defined

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week05" style="color:black;">Week 5: First ML Model</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# <div style="background-color:#E3D8E6">
#
# **Supervised learning:** Training data is **labelled**.
# - ***Regression***:  predict a value from a continuous space
# - ***Classification***: distinguish between discrete types of entities
#
# **Unsupervised learning:** Training data is **unlabelled** - model built on other properties
# - ***Clustering***: grouping data into categories without any prior information
#
# <div style="background-color:#DFDFEA">
#
# **Instance-based learning:** find where the test data targets are the **same** as rge **nearest** training data points
#
# **Model-based learning:** take a few instances & build a more general **model** - refined through training & validation - optimize internal **parameters** (learned from training data)
#
# </div>

# %% [markdown]
# ## <h2><a id="kNN">k-Nearest Neighbours (k-NN)</a></h2>

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# - ***Regression***:  labels are continuous variables. The label of the new data point $\mathbf{X}$ is chosen to be the mean of the labels of its $k$-nearest neighbours.
# - ***Classification***: labels refer to **categories**. The new data point $x$ is assigned to the **most frequent class of its $k$-nearest neighbours**
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# <a style="color:#7F62AA; text-decoration: None">**Euclidean distance:** $d(\mathbf{p},\mathbf{q})=\sqrt{\sum_{i=1}^{D}\left(q_{i}-p_{i}\right)^{2}}$

# %%
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
import matplotlib.cm as cm

X, y = make_blobs(300,2, center_box=(-5,5), centers = 2, random_state = 2) 
df_toy = pd.DataFrame(X,columns=['Feature 1','Feature 2'])
pd.plotting.scatter_matrix(df_toy, figsize = (6,6), c = y, hist_kwds={'edgecolor':'black','alpha':0.5}, cmap = cm.cividis)
# Out:
# array([[<Axes: xlabel='Feature 1', ylabel='Feature 1'>,
#         <Axes: xlabel='Feature 2', ylabel='Feature 1'>],
#        [<Axes: xlabel='Feature 1', ylabel='Feature 2'>,
#         <Axes: xlabel='Feature 2', ylabel='Feature 2'>]], dtype=object)

# %% [markdown]
# ### 1. Prepare the training and testing data.

# %%
from sklearn.model_selection import train_test_split

# Take 20% of the data out for testing
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 3)

# %% [markdown]
# ### 2.  Define the kNN algorithm.

# %%
from sklearn.neighbors import KNeighborsClassifier

# These are hyperparameters of the k-NN algorithm
neighbours = 20
weights = 'uniform'

knn_toy = KNeighborsClassifier(neighbours, weights = weights)

# %%
# Varying hyperparameters
list_of_weights = ['uniform','distance']
list_of_neighbors = [3, 8, 15, 25, 40]
list_of_hyperparameters = [(w, n) for w in list_of_weights for n in list_of_neighbors]

# %% [markdown]
# ### 3. Fit using the training data and predict using the testing data.

# %%
knn_toy.fit(X_train,y_train)
y_pred = knn_toy.predict(X_test)

# %% [markdown]
# ### 4. Calculate the classification accuracy score.
#
# \begin{equation*}
#     \text{Accuracy} = \frac{N_{\text{correct}}}{N_{\text{total}}},
# \end{equation*}

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### 5. Cross-Validation

# %% [markdown]
# Break down the training set into **folds**, train the model with all but one of these folds and evaluate with remaining fold:
#
# <div style="background-color:#E3D8E6">
#
# (Optional mathematical details)
#
# Cross validation score divides the total set into $T$ equally sized subsets $S$:
# \begin{equation*}
# \mathcal{S}=\bigcup_{t=1}^{T}\mathcal{S}_{t} \; \text{and} \; |\mathcal{S}_{t}|=\frac{|\mathcal{S}|}{T},
# \end{equation*}
#
# \begin{equation*}
# \text{Accuracy}_t = \frac{N_{\text{correct}}^t}{N_{\text{total}}^t} \Rightarrow \langle\text{Accuracy}\rangle=\frac{1}{T}\sum_{t=1}^{T}\text{Accuracy}_t.
# \end{equation*}

# %%
from sklearn.model_selection import cross_val_score # splitted into 5 folds by default

cv_list = cross_val_score(knn_toy, X_train, y_train) # returns 5 accuracy values, one for each fold.

cv_score = cv_list.mean()

cv_list
# Out:
# array([1.        , 1.        , 0.95833333, 0.95833333, 1.        ])

# %% [markdown]
# ## <h2><a id="svm">Support Vector Machine (SVM)</a></h2>

# %% [markdown]
# ### Classification (SVC)

# %%
from sklearn.svm import SVC

# C = 1
# kernel = 'linear'

list_of_C = [1.0, 10.0, 100.0]
list_of_kernels = ['linear','poly','rbf','sigmoid']

list_of_hyperparameters = [(C, k) for C in list_of_C for k in list_of_kernels]


SVC_df = pd.DataFrame(columns=['C','kernel','test_accuracy','mean_cv_score'])
for C, kernel in list_of_hyperparameters:
    model = SVC(C = C, kernel = kernel)
    cv = cross_val_score(model, X_train, y_train)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    model_dict = {'C':C, 'kernel':kernel,'test_accuracy':acc,'mean_cv_score':cv.mean()}
    SVC_df = pd.concat([SVC_df, pd.DataFrame([model_dict])])

# display(SVC_df)
# Out:
# C:\Users\cissi\AppData\Local\Temp\ipykernel_18932\3826347331.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   SVC_df = pd.concat([SVC_df, pd.DataFrame([model_dict])])

# %% [markdown]
# ### Regression (SVR)

# %%
from sklearn.svm import SVR

kernel = 'poly'
degree = 4
epsilon = 10
coef0 = 2
C = 1

poly_model = SVR(kernel = kernel,degree = degree,epsilon = epsilon,coef0 = coef0,C = C)
poly_model.fit(X_train, y_train)
poly_model.predict(X_test)   #<--- returns a list of prediction for the X_test.
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week06" style="color:black;">Week 6: Performance Metrics</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# ## <h2><a id="perfmetrics">Performance metrics in classification</a></h2>

# %% [markdown]
# ### **Confusion matrix**<hr style="height: 2px; border: none; background-color: #C9CAE1;">
#
#
# For binary classification problem with $y_i \in \{+1, -1\}$,
#
# * **True positive (TP)**: Samples in the +1 class that are correctly identified as the +1 class
# <br>
#
# * **False positive (FP)**: Samples in the -1 class that are incorrectly identified as the +1 class (type I error)
# <br>
#
# * **True negative (TN)**: Samples in the -1 class that are correctly identified as the -1 class
# <br>
#
# * **False negative (FN)**: Samples in the +1 class that are incorrectly identified as the -1 class (type II error)
#
# <div style="background-color:#DFDFEA">
#
# * **Accuracy**: Proportion of samples that are classified correctly
# <br>
#
# \begin{equation*}
# \text{Accuracy} = \frac{\text{Number of correct predictions}}{\text{Total number of predictions}} = \frac{TP + TN}{TP + TN + FP + FN}
# \end{equation*}
# <br>
#
# * **Fall-out or False Positive Rate**: Proportion of points with $y$ = -1 that are incorrectly predicted as $\hat{y}$ = +1
# <br>
#
# \begin{equation*}
# \text{Fall-out} = \frac{\text{+1 predictions with true class -1}}{\text{Points with true class -1}} = \frac{FP}{FP + TN}
# \end{equation*}
# <br>
#
# * **Precision**: Proportion of points with predicted to have class +1 that have true class +1 i.e. fraction of predictions of class +1 that are correct
# <br>
#
# \begin{equation*}
# \text{Precision} = \frac{\text{+1 class predictions with true class +1}}{\text{Predictions of class +1}} = \frac{TP}{TP + FP}
# \end{equation*}
# <br>
#
# * **Recall or True Positive Rate**: Fraction of points with true class +1 that are correctly identified as class +1
# <br>
#
# \begin{equation*}
# \text{Recall} = \frac{\text{+1 class predictions with true class +1}}{\text{Points with true class +1}} = \frac{TP}{TP + FN}
# \end{equation*}

# %% [markdown]
# ### <h3><a style="color:#5575a9; text-decoration: None">The Receiver Operating Characteristic (ROC) curve</a></h3>

# %% [markdown]
# The receiver operating characteristic (ROC) curve is the plot of fallout (FP rate) against recall (TP rate), as a function of decision boundary value. In general, it is used to evaluate the effectiveness of a classifier.
#
# **AUC (area-under-curve) score**
# * Complete metric for the area under the ROC curve is referred to as **ROC-AUC**
# * A perfect classifier has a ROC-AUC score of 1 (ROC curve = straight line y=x)
# * A random classifier has a ROC-AUC score of 0.5
# * The worst possible classifier has a ROC-AUC score of 0.

# %%
# Method 1
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(svc1, X_test, y_test)
plt.gca().set_title('Model 1',fontsize = 20)
RocCurveDisplay.from_estimator(svc2, X_test, y_test)
plt.gca().set_title('Model 2',fontsize= 20)

# %%
# Method 2
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

y_score1 = svc1.decision_function(X_test) # Calculate scores for test points
y_score2 = svc2.decision_function(X_test)

fpr1, tpr1, thresholds1 = roc_curve(y_test, y_score1) # Find ROC curve values
fpr2, tpr2, thresholds2 = roc_curve(y_test, y_score2)

fig, ax = plt.subplots(1,1,figsize = (6,4), dpi = 120)

ax.plot(fpr1, tpr1,color='#D55E00', label='Model 1',ls='--') # Plot the ROC curve
ax.plot(fpr2, tpr2, color='#56B4E9', label = 'Model 2', ls = '--')
ax.set_xlabel('False positive rate',fontsize = 18)
ax.set_ylabel('True positive rate', fontsize = 18)

print('Model 1 ROC-AUC: {:.3f}'.format(roc_auc_score(y_test, y_score1)))
print('Model 2 ROC-AUC: {:.3f}'.format(roc_auc_score(y_test, y_score2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 5
#       2 from sklearn.metrics import roc_curve
#       3 from sklearn.metrics import roc_auc_score
# ----> 5 y_score1 = svc1.decision_function(X_test) # Calculate scores for test points
#       6 y_score2 = svc2.decision_function(X_test) # Calculate scores for test points
#       8 fpr1, tpr1, thresholds1 = roc_curve(y_test, y_score1) # Find ROC curve values
#
# NameError: name 'svc1' is not defined

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
#
# **ROC curve for a kNN classifier:**
#
#  It does not implement a ```decision_function```. However, from the ```roc_curve``` [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html) you can see that we can pass a list of probabilities of the positive class. From a k-NN classifier, we can obtain this using the ```predict_proba``` function. This returns an array of shape ($n_{\text{samples}}$, $n_{\text{classes}}$) where each element is the probability of the relevant class for that sample.
#
# We need to pass the probability of the positive class, which corresponds to the second column: ```knn.predict_proba(X_test)[:,1]```. We can then pass this to ```roc_curve``` and ```roc_auc_score``` with ```y_test``` to calculate the score. The ```RocCurveDisplay``` will automatically do this, so if you use that function you do not need to worry about this.
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="metricregression">Performance metrics in regression</a></h2>

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
#
# \begin{align*}
# \text{Mean absolute error (MAE)}:\qquad\qquad & \text{MAE} = \frac{1}{N}\sum_{i = 1}^N|y_i - \hat{y}_i| \\[10pt]
# \text{Mean squared error (MSE)}:\qquad\qquad & \text{MSE} = \frac{1}{N}\sum_{i = 1}^N(y_i - \hat{y}_i)^2 \\[10pt]
# \text{Root-mean squared error (RMSE)}:\qquad\qquad & \text{RMSE} = \sqrt{\frac{1}{N}\sum_{i = 1}^N(y_i - \hat{y}_i)^2} \\
# \end{align*}
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
# **Coefficient of determination $R^2$**, compares the performance of the model against a model that just predicts the mean of the training data; in other words, it tells you how much the model can explain the variance of the data. The value can become arbitrarily negative as model prediction can be arbitrarily bad.
#
# \begin{equation*}
# R^2 = 1 - \frac{\sum_{i = 1}^N(y_i - \hat{y}_i)^2}{\sum_{i = 1}^N (y_i - \bar{y})^2},
# \end{equation*}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean absolute error : {}".format(mae))
print("Mean squared error : {}".format(mse))
print("Root-mean squared error : {}".format(rmse))
print("R2 score : {}".format(r2))

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# ### Pre-processing the data

# %% [markdown]
# Sometimes, we need to perform some pre-processing on our data in order to simplify our data or make it easier for our algorithm to solve the problem:
#
# * **Rescaling:** transforming your data into a specific range, e.g. such that all of your input features are between 0 and 1 or between -1 and 1. If the scale between different features is significantly different then one feature can influence the training more than others.
# <br>
#
# * **Encoding categorical features:** some datasets will have non-numeric data, e.g. whether a house has a garden or not, which must be transformed into numerical data for the purposes of training a machine learning algorithm.
# <br>
#
# * **Discretization:** turning a continuous variable into a series of categories, e.g. applying binning to data.

# %%
from sklearn import preprocessing
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline

scaler = preprocessing.StandardScaler() # scales data to a standard normal distribution
svr = SVR(kernel = 'linear')

pipeline = make_pipeline(scaler, svr) 

# pipeline.fit(X_train, y_train)
# predictions = pipeline.predict(X_test)

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week07" style="color:black;">Week 7: Decision Trees
# </a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# * The **root node** is the first node of the decision tree.
#
# * **Internal nodes** (or sometimes just nodes) are nodes with branches to and away from them.
#
# * A **leaf** is a node at the end of a branch, with no further branches. This is where we make a prediction.
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="treeclass">Decision Trees for classification</a></h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris['data'],iris['target'], test_size = 0.2, random_state = 20) 

clf = tree.DecisionTreeClassifier(max_depth = 2, random_state = 1)

clf.fit(X_train, y_train)

pred = clf.predict(X_test)
print(accuracy_score(y_test, pred))

tree.plot_tree(clf, filled = True)
# Out:
# 0.9
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.666\nsamples = 120\nvalue = [42, 39, 39]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.65\ngini = 0.5\nsamples = 78\nvalue = [0, 39, 39]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.095\nsamples = 40\nvalue = [0, 2, 38]')]

# %% [markdown]
# <div style="background-color:#DFDFEA">
#
#
# The cut positions are chosen to optimise some function of the model prediction on training data. For classification, we need some function that quantifies how good our data split is, i.e. how well it separates our different classes. This is given by the **Gini impurity**:
#
# \begin{equation*}
# G_i = 1 - \sum_k p_{i, k}^2,
# \end{equation*}
#
# where $\sum_k p_{i, k}^2$ is therefore the total probability of correctly labelling a randomly selected sample with a randomly selected label at node $i$, so the Gini impurity $G_i$ is the probability of incorrectly labelling a randomly selected sample.
#
# Alternative option: **log loss** or the **entropy**:
#
# \begin{equation*}
# H_i = -\sum_k p_{i, k}\log_2\left(p_{i,k}\right)
# \end{equation*}
#
# The Gini and entropy of given node is 0 if it only has samples of one class. Regardless of which loss function we use, the model decides on the the cut at each node by minimising the loss function for that node.

# %% [markdown]
# ## <h2><a id="treereg">Decision Trees for regression</a></h2>

# %%
np.random.seed(42)

# Generate training data
X = 6*np.random.rand(1000,1) - 3
y = 0.5*X**2 + X + 2 + np.random.randn(1000,1)
plt.scatter(X,y,color='#9EC6E1',s = 3, label = 'Data')

reg = tree.DecisionTreeRegressor(max_depth = 2, random_state = 1)
reg.fit(X,y)
xs = np.linspace(-3,3,1000)
ys = reg.predict(xs.reshape(-1,1))
score = accuracy_score(y_test, pred)
plt.plot(xs, ys, color='black',label='Decision tree prediction')
plt.legend()
plt.show()

tree.plot_tree(reg, filled = True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= 1.767\nsquared_error = 5.463\nsamples = 1000\nvalue = 3.577'),
#  Text(0.25, 0.5, 'x[0] <= 0.542\nsquared_error = 1.729\nsamples = 791\nvalue = 2.598'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'squared_error = 1.257\nsamples = 599\nvalue = 2.205'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 1.207\nsamples = 192\nvalue = 3.827'),
#  Text(0.75, 0.5, 'x[0] <= 2.345\nsquared_error = 2.257\nsamples = 209\nvalue = 7.28'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 1.149\nsamples = 91\nvalue = 6.168'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 1.421\nsamples = 118\nvalue = 8.138')]

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# ### sklearn Decision Tree syntax

# %% [markdown]
# For a `DecisionTreeClassifier`, the `score` method finds the mean accuracy on test data, while for a `DecisionTreeRegressor` the `score` method finds the coefficient of determination ($R^2$ score).
#
# Hyperparameters:
# * `max_depth`: the maximum depth of the tree, i.e. how many layers of nodes are allowed. If the value passed is `None`, the tree continues "growing" until all leaves are pure (either only one class, or perfect prediction on training data) or `min_samples_split` is reached.
#
# * `min_samples_split` (**evaluated before splitting**): the minimum number of samples in a set required to consider splitting an internal node, i.e. we require $n_m$ > `min_samples_split` to split the dataset $Q_m$ into two datasets.
#
# * `min_samples_leaf` (**evaluated after splitting**): the number of samples from the training dataset required to be at a leaf node. A split at *any* depth will only be considered if it leaves at least `min_samples_leaf` training samples in each of the left and right branches.
#
# If any of the conditions are not met, it automatically becomes a leaf.
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="overfitting">Demonstration of overfitting with decision tree</a></h2>

# %% [markdown]
# We can create a decision tree that is *too* large for our dataset, so the training results in a model fitted very well to the training data but without good generalisation. Decision trees tend to overfit the data.

# %%
from sklearn.datasets import make_moons
from matplotlib.colors import ListedColormap

X, y = make_moons(n_samples = 300, noise = 0.25, random_state = 42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

clf = tree.DecisionTreeClassifier(max_depth = 100, random_state = 1)
clf.fit(X_train, y_train)

# Visualise the decision tree
fig = plt.figure(figsize = (15,15))
_ = tree.plot_tree(clf, filled = True, fontsize = 12)

x1s, x2s = np.linspace(-1.8,2.7,100), np.linspace(-1.5,1.8,100)
x1, x2 = np.meshgrid(x1s, x2s)
X_new = np.c_[x1.ravel(), x2.ravel()]
y_pred = clf.predict(X_new).reshape(x1.shape)
custom_cmap = ListedColormap(['#E3D8E6','black','#9EC6E1'])

# Plot the decision boundary and the test data
fig, ax = plt.subplots(1,1,figsize = (10,6),dpi = 150)
ax.contourf(x1,x2,y_pred,alpha = 0.2, cmap = custom_cmap,zorder = 0)
ax.contour(x1,x2,y_pred,cmap = custom_cmap,zorder = 0, alpha = 0.5)
ax.scatter(X_train[:,0][y_train==0],X_train[:,1][y_train==0],color='#E3D8E6',marker='s',label= 'Class 1',zorder = 1,edgecolor='black',lw = 0.5)
ax.scatter(X_train[:,0][y_train==1],X_train[:,1][y_train==1],color='#9EC6E1',marker='^',label='Class 2',zorder = 1,edgecolor='black',lw = 0.5)
ax.set_xlabel('$X_1$',fontsize = 16)
ax.set_ylabel('$X_2$',fontsize = 16)
ax.tick_params(which='both',labelsize= 12,direction='in',top=True,right=True)
ax.grid(color='xkcd:dark blue',alpha = 0.2)
ax.legend(loc='upper right',fontsize = 12, framealpha = 1)
ax.set_title('Training data',fontsize = 20)

# Plot the decision boundary and test data
fig, ax = plt.subplots(1,1,figsize = (10,6),dpi = 150)
ax.contourf(x1,x2,y_pred,alpha = 0.2, cmap = custom_cmap,zorder = 0)
ax.contour(x1,x2,y_pred,cmap = custom_cmap,zorder = 0, alpha = 0.5)
ax.scatter(X_test[:,0][y_test==0],X_test[:,1][y_test==0],color='#E3D8E6',marker='s',label= 'Class 1',zorder = 1,edgecolor='black',lw = 0.5)
ax.scatter(X_test[:,0][y_test==1],X_test[:,1][y_test==1],color='#9EC6E1',marker='^',label='Class 2',zorder = 1,edgecolor='black',lw = 0.5)
ax.set_xlabel('$X_1$',fontsize = 16)
ax.set_ylabel('$X_2$',fontsize = 16)
ax.tick_params(which='both',labelsize= 12,direction='in',top=True,right=True)
ax.grid(color='xkcd:dark blue',alpha = 0.2)
ax.legend(loc='upper right',fontsize = 12, framealpha = 1)
ax.set_title('Test data',fontsize = 20)

print("Test accuracy = {}".format(accuracy_score(y_test,clf.predict(X_test))))
# Out:
# Test accuracy = 0.9166666666666666

# %% [markdown]
# <!-- <hr style="height: 2px; border: none; background-color: #C9CAE1;"> -->
# <hr style="border:2px solid #C9CAE1">
#
# ## <h2><a style="color:#7F62AA;" id="ensemble">Ensemble Learning (code non-examinable)</a></h2>

# %% [markdown]
# Use *many* individual models (which may be the same type of model or different ones, e.g. a mixture of SVMs and DTs), which make their own independent predictions, and we use some **voting scheme** to determine the ensemble prediction based on the individual predictions of each model. We use different voting schemes for classification and regression, and we can do things in a couple different ways:
#
# * For classification, we can use either:
#     * Hard voting: the prediction is the most common prediction across all the models
#     * Soft voting: the prediction is the most probable prediction across all the models i.e. predicts the class with the greatest total probability across all models in the ensemble
# <br>
# <br>
#
# * For regression, we can predict either the mean prediction across all models in the ensemble, or a weighted mean. This lets us assign different weights to different models.

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784',as_frame = False)
X, y = mnist['data'], mnist['target']
X_train, X_test, y_train, y_test = X[:20000],X[20000:],y[:20000],y[20000:]

svc_clf = SVC(max_iter = 20)
tree_clf = tree.DecisionTreeClassifier(max_depth = 20, random_state = 1)

voting_clf = VotingClassifier(estimators = [('svc',svc_clf),('tree',tree_clf)], voting = 'hard')

# train each classifier and evaluate their accuracy on the test set
for clf in (svc_clf, tree_clf, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print('{} accuracy: {}'.format(clf.__class__.__name__, accuracy_score(y_test, y_pred)))
# Out:
# c:\Users\cissi\anaconda3\envs\tf\Lib\site-packages\sklearn\svm\_base.py:313: ConvergenceWarning: Solver terminated early (max_iter=20).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC accuracy: 0.83374
# DecisionTreeClassifier accuracy: 0.83682
# c:\Users\cissi\anaconda3\envs\tf\Lib\site-packages\sklearn\svm\_base.py:313: ConvergenceWarning: Solver terminated early (max_iter=20).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# VotingClassifier accuracy: 0.85216

# %% [markdown]
# <hr style="border:2px solid #C9CAE1">

# %% [markdown]
# ## <h2><a id="forest">Random Forests</a></h2>

# %% [markdown]
# When we train an ensemble model out of only decision trees = random forest. We need to vary the training data given to each model:
#
# * **Bagging**: short for "bootstrap aggregation", refers to taking samples from the training dataset *with replacement*. Each sample in the complete training dataset can be selected more than once for a given individual model training dataset.
# <br>
#
# * **Pasting**: rather than replacing training samples after they have been selected, samples are drawn from the complete dataset *without replacement*. Each sample in the complete training dataset can only be selected once for a given individual model training dataset.
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %%
from sklearn.datasets import make_moons
from sklearn.ensemble import RandomForestClassifier

X, y = make_moons(n_samples = 300, noise = 0.25, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

clf = RandomForestClassifier(n_estimators = 500, # Number of different estimators (trees) in the forest
                             max_samples = 100, # Number of samples to draw from the training data to train each tree
                             bootstrap = True, 
                             n_jobs = 4, # Number of CPU cores to use for training & prediction
                             oob_score = True, # Whether to calculate the OOB score to test the generalisation of the model
                             max_leaf_nodes = 20, # Limit individual tree size by requiring no more than 20 leaf nodes
                             random_state = 1) 

clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_leaf_nodes=20, max_samples=100, n_estimators=500,
#                        n_jobs=4, oob_score=True, random_state=1)

# %%
from matplotlib.colors import ListedColormap

x1s, x2s = np.linspace(-1.8,2.7,100), np.linspace(-1.5,1.8,100)
x1, x2 = np.meshgrid(x1s, x2s)
X_new = np.c_[x1.ravel(), x2.ravel()]
y_pred = clf.predict(X_new).reshape(x1.shape)
custom_cmap = ListedColormap(['#E3D8E6','black','#9EC6E1'])

fig, ax = plt.subplots(1,1,figsize = (10,6),dpi = 150)
ax.contourf(x1,x2,y_pred,alpha = 0.2, cmap = custom_cmap,zorder = 0)
ax.contour(x1,x2,y_pred,cmap = custom_cmap,zorder = 0, alpha = 0.5)
ax.scatter(X_train[:,0][y_train==0],X_train[:,1][y_train==0],color='#E3D8E6',marker='s',label= 'Class 1',zorder = 1,edgecolor='black',lw = 0.5)
ax.scatter(X_train[:,0][y_train==1],X_train[:,1][y_train==1],color='#9EC6E1',marker='^',label='Class 2',zorder = 1,edgecolor='black',lw = 0.5)
ax.set_xlabel('$X_1$',fontsize = 16)
ax.set_ylabel('$X_2$',fontsize = 16)
ax.tick_params(which='both',labelsize= 12,direction='in',top=True,right=True)
ax.grid(color='xkcd:dark blue',alpha = 0.2)
ax.legend(loc='upper right',fontsize = 12, framealpha = 1)
ax.set_title('Training data, random forest',fontsize = 20)

pred = clf.predict(X_test)
print('OOB score = {}'.format(clf.oob_score_))
print('Test accuracy = {}'.format(accuracy_score(y_test,pred)))
# Out:
# OOB score = 0.8916666666666667
# Test accuracy = 0.9666666666666667

# %% [markdown]
# ## <h2><a id="BDTs">Boosted Decision Trees (BDTs)</a></h2>

# %% [markdown]
# Essentially, the idea is to train a large number of models that are only slightly better than randomly guessing and combine to produce a single ensemble model with accurate prediction. There are many possible boosting algorithms, but we will talk about two in detail and then present one more that is one of the best tools available for training boosted decision trees.

# %% [markdown]
# ### <h3><a style="color:#5575a9; text-decoration: None">XGBoost(e**X**treme **G**radient **Boost**)</a></h3>

# %%
from sklearn.datasets import make_moons
from xgboost import XGBClassifier

X, y = make_moons(n_samples = 300, noise = 0.25, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

clf = XGBClassifier(random_state = 1)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

print("Accuracy = {}".format(accuracy_score(y_test, pred)))

x1s, x2s = np.linspace(-1.8,2.7,100), np.linspace(-1.5,1.8,100)
x1, x2 = np.meshgrid(x1s, x2s)
X_new = np.c_[x1.ravel(), x2.ravel()]
y_pred = clf.predict(X_new).reshape(x1.shape)
custom_cmap = ListedColormap(['#E3D8E6','black','#9EC6E1'])

fig, ax = plt.subplots(1,1,figsize = (10,6),dpi = 150)
ax.contourf(x1,x2,y_pred,alpha = 0.2, cmap = custom_cmap,zorder = 0)
ax.contour(x1,x2,y_pred,cmap = custom_cmap,zorder = 0, alpha = 0.5)
ax.scatter(X_train[:,0][y_train==0],X_train[:,1][y_train==0],color='#E3D8E6',marker='s',label= 'Class 1',zorder = 1,edgecolor='black',lw = 0.5)
ax.scatter(X_train[:,0][y_train==1],X_train[:,1][y_train==1],color='#9EC6E1',marker='^',label='Class 2',zorder = 1,edgecolor='black',lw = 0.5)
ax.set_xlabel('$X_1$',fontsize = 16)
ax.set_ylabel('$X_2$',fontsize = 16)
ax.tick_params(which='both',labelsize= 12,direction='in',top=True,right=True)
ax.grid(color='xkcd:dark blue',alpha = 0.2)
ax.legend(loc='upper right',fontsize = 12, framealpha = 1)
ax.set_title('Training data, XGBoost',fontsize = 20)
# Out:
# Accuracy = 0.9666666666666667
# Text(0.5, 1.0, 'Training data, XGBoost')

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week09" style="color:black;">Week 9: Introduction to Neural Networks</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# **Neurons:** take sets of inputs and produce an output according to the weights and bias of that neuron: $y = \mathbf{w}\cdot\mathbf{X} + b$
#
# **Activation functions:** $y = \sigma(\mathbf{w}\cdot\mathbf{X} + b)$. Without activation functions, we can only ever approximate linear functions or classify linearly separable data
#
# * Sigmoid:
# $\sigma(z) = \frac{1}{1 + e^{-z}}$
#
# * tanh: $\sigma(z) = \frac{e^z - e^{-z}}{e^z + e^{-z}}$
#
# * ReLU (Rectified Linear Unit): $\sigma (z) = \begin{cases}
#   0  & z \lt 0 \\
#   z & \text{otherwise}
# \end{cases}$
#
# **Multilayer NN:** Arrange neurons into layers, the ouputs from one set of neurons = inputs to the next set. Each neuron in a layer can take inputs from *every* neuron in the previous layer with independent weight for each of these: a given layer of neurons has a *matrix* of weights, corresponding to every possible pair of input neuron and output neuron.
# * Input layer (first layer) $\to$ hidden layers $\to$ output layer (last layer)
# * $\color{#7F62AA} f_i(\mathbf{X}_i) = \sigma_i (\mathbf{w}_i \cdot \mathbf{X}_i + b_i) \Rightarrow \mathbf{y} = f_N\left(f_{N - 1} \left(\cdots \left(f_{1} \left(\mathbf{X}\right) \right) \right) \right)$
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="pytorch">PyTorch</a></h2>

# %%
import torch
import torch.nn as nn

torch.manual_seed(31337)

# %% [markdown]
# **PyTorch Basics**

# %%
X_int = torch.tensor([1,2,3,4],dtype = torch.int) # 32 bit integer
X_float = torch.tensor([1,2,3,4],dtype = torch.float) # 32 bit float
X_bool = torch.tensor([0,1,1,0], dtype = torch.bool) # Boolean

empty = torch.empty(3,5) # Empty array of shape (3, 5)
ran = torch.rand(2, 4) # 
zeros = torch.zeros(2,3,4) # Array of 0s of shape (2, 3, 4)
ones = torch.ones(6) # Array of 1s of shape (6,)

# %%
inputs = 2
outputs = 4

linear = nn.Linear(inputs, outputs) # Layer that takes in 2 inputs and produces 1 output
# print(linear.weight)
# print(linear.bias)
samples = torch.rand(10,2)
output = linear(samples) # Output of the linear layer for the input samples

# Activation functions
activation = nn.ReLU() # Rectified Linear Unit activation function
output_activated = activation(output) # Output of the linear layer after applying the activation function
# Out:
# Activation on output of a single layer: tensor([0.0000, 3.2561, 0.0000, 7.4181], grad_fn=<ReluBackward0>)

# %% [markdown]
# **Multilayer models**

# %%
model = nn.Sequential(nn.Linear(2, 10), # 2 input features
                      nn.Sigmoid(), # Activation function
                      nn.Linear(10,1)) # Hidden layer with 10 neurons, 1 output feature

print('Model prediction for single sample: {}\n'.format(model(torch.Tensor([8,9]))))

print('Model prediction for multiple samples: {}'.format(model(samples)))
# Out:
# Model prediction for single sample: tensor([-0.2134], grad_fn=<ViewBackward0>)
#
# Model prediction for multiple samples: tensor([[-0.3005],
#         [-0.3191],
#         [-0.3133],
#         [-0.2947],
#         [-0.3178],
#         [-0.3268],
#         [-0.3066],
#         [-0.2933],
#         [-0.2988],
#         [-0.3108]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# **Dataset and DataLoader**

# %%
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader

X_torch = torch.randn(200, 2)
y_torch = torch.randn(200,1)

dataset = TensorDataset(X_torch, y_torch)
dataset_train, dataset_test = random_split(dataset, lengths = [0.8,0.2]) # Split dataset into separate datasets for training & testing

dloader_train = DataLoader(dataset_train, batch_size = 32, shuffle = True) # Generally good to keep batch size as a power of 2 for faster calculations, and to shuffle the data for training
dloader_test = DataLoader(dataset_test, batch_size = 32, shuffle = True)

for X_batch, y_batch in dloader_train:
    print("X_batch : \n {}".format(X_batch)) # Shape of X_batch is (32, 2) as we have 32 samples in each batch and 2 features for each sample
    print("y_batch : \n {}".format(y_batch)) # Shape of y_batch is (32, 1) as we have 32 samples in each batch and 1 target value for each sample
# Out:
# X_batch :
#  tensor([[ 0.9518,  0.9786],
#         [-1.1563, -1.3156],
#         [-0.2748, -0.4522],
#         [-1.5211,  1.0973],
#         [ 1.7161, -0.7675],
#         [-1.0839, -0.0884],
#         [-0.5833, -0.2431],
#         [-1.1111, -0.4838],
#         [-0.2797,  0.5848],
#         [-0.4111,  0.3449],
#         [-3.2339, -1.3753],
#         [-0.6363, -0.7334],
#         [-1.1898,  0.9123],
#         [-0.3939,  0.4214],
#         [-1.2348,  1.2716],
#         [ 0.6509, -0.5528],
#         [-0.1883, -0.9900],
#         [ 1.2466,  0.2261],
#         [-0.1417, -0.0937],
#         [ 0.1050, -0.0221],
#         [ 1.2909,  1.8735],
#         [ 0.2201, -0.4156],
#         [ 0.1598, -0.0149],
#         [-0.1692, -1.4115],
#         [ 0.7262,  1.2773],
#         [-0.6748, -0.1803],
#         [-1.1387, -0.4115],
#         [-0.5092,  2.3907],
#         [-2.0154, -2.3212],
#         [-0.8952,  0.6588],
#         [ 0.7823, -0.6285],
#         [ 2.0323,  0.9769]])
# y_batch :
# ...

# %% [markdown]
# ## <h2><a id="NNL">Neural Network Learning</a></h2>

# %% [markdown]
# ### <h3><a id="understandnnl" style="color:#5575a9; text-decoration: None">Understanding NNL</a></h3>
# <!-- <hr style="height: 2px; border: none; background-color: #DFDFEA;"> -->

# %% [markdown]
# **Data**
# * **Training dataset:** used to train the model.
#
# * **Validation data:** used during training to monitor generalisation of the network. Want to ensure loss on validation data improves as well as the training data; if validation loss stops improving while training loss continues to improve, this is a sign of *overfitting*.
#
# * **Test data:** used after *all* training is finished to evaluate final performance.
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# **Loss functions:** minimized wrt *all* individual weights and biases across the entire network - ***gradient descent*** wrt all parameters
# * **For classification:** Require normalization (ouput = probabilities); minimize ***cross entropy*** `nn.BCELoss()`
# * **For regression:** Normalization not required; minimize *mean squared error*
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# **Backpropagation:** start from the last layer of the NN, calculate all of the relevant loss function derivatives, work backwards through the network
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# **Stochastic gradient descent:** `torch.optim.SGD` break data into random batches, update by the gradient of the loss function averaged across the data in the batch (save time). In each epoch, we update the weights for each batch, then reshuffle the batches between epochs
# <!-- <hr style="height: 2px; border: none; background-color: #DFDFEA;"> -->

# %% [markdown]
# <div style="background-color:#DFDFEA">
# The overall procedure for training our model in a single epoch therefore goes as follows: <a id='algorithm'></a>
#
# 1. Obtain a single batch of our data
# <br>
#
# 1. Perform a forward pass, i.e. calculate prediction on the training data in the batch
# <br>
#
# 1. Zero the gradients on our optimizer in preparation for calculating gradients of the batch
# <br>
#
# 1. Calculate the loss from the prediction and the batch training targets
# <br>
#
# 1. Perform a backward pass i.e. calculate the gradients of the loss function with respect to each model parameter
# <br>
#
# 1. Use the gradients to perform a step of the optimizer and update the model parameters
# <br>
#
# 1. Repeat the process for the next batch until all batches have been used to update the model parameters
#
# We will see this implemented in code in [Section Four](#code-algorithm).

# %% [markdown]
# <hr style="height: 2px; border: none; background-color: #E3D8E6;">
#
# **Activation functions**
# * **Vanishing gradient problem**: if the expectation of the activation function gradient is considerably $\ll 1$, for parameters far from the output $\frac{\partial L}{\partial p}$ will become extremely close to 0, resulting in very small steps every update. Results in slow or stalled learning.
# <br>
#
# * **Exploding gradient problem**: if the expectation of the activation function gradient is $\gg 1$, $\frac{\partial L}{\partial p}$ will be very large for layers far from the output, so can cause wild fluctuations in the weights with every update by overshooting the minimum. This makes it difficult for the model to train effectively.
#
# Activation functions such as **sigmoid and tanh are explicitly bad** for ***deep*** neural networks because of these reasons.
#
# In general, a good choice for a deep network is a variant on the ReLU (issue: *dead neurons*), with such variants including:
#
# * $
# \text{LeakyReLU}(z) = \begin{cases}
#   z  & z \geq 0 \\
#   \alpha\cdot z & \text{otherwise}
# \end{cases}$
#
# * $
# \text{ELU}(z) = \begin{cases}
# z & z \gt 0 \\
# \alpha\cdot (e^{z} - 1) & \text{otherwise}
# \end{cases}$
#
# * $
# \text{Swish}(z) = \frac{z}{1 + e^{-z}}$
# <hr style="height: 2px; border: none; background-color: #E3D8E6;">

# %% [markdown]
# ### <h3><a id="codennl" style="color:#5575a9; text-decoration: None">Code for training NNL with PyTorch</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# #### Example data

# %%
from sklearn.datasets import make_classification
import numpy as np

n_samples = 300
np.random.seed(42)

X, y = make_classification(n_features = 2, 
                           n_redundant = 0, 
                           n_samples = n_samples, 
                           n_informative = 2, 
                           random_state = 6, 
                           class_sep = 1, 
                           n_clusters_per_class=1)

X_torch = torch.tensor(X).float()
y_torch = torch.tensor(y).float()

# %% [markdown]
# #### Model

# %%
# Define model
torch.manual_seed(5)

model = nn.Sequential(nn.Linear(2,10),
                      nn.ReLU(),
                      nn.Linear(10,1),
                      nn.Sigmoid())

# Define dataset
dataset = TensorDataset(X_torch, y_torch)
dataset_train, dataset_validate, dataset_test = random_split(dataset, lengths = [0.6,0.2,0.2], generator = torch.Generator().manual_seed(2)) # Split dataset into separate datasets for training & testing

dloader_train = DataLoader(dataset_train, batch_size = 32, shuffle = True)
dloader_validate = DataLoader(dataset_validate, batch_size = 32, shuffle = True)

# Define loss function and optimizer
# loss_fcn = nn.BCELoss() # Default reduction is 'mean' which means the loss is averaged over the batch, can also set reduction to 'sum' to get the total loss for the batch.
loss_fcn = nn.BCELoss(reduction='sum')
optimizer = torch.optim.SGD(params = model.parameters(), 
                            lr = 0.01) # Other parameters include momentum, weight_decay, etc.

# %% [markdown]
# **Training Loop** - the number of times we run the training loop = number of *epochs*

# %%
def train_epoch():
    tot_loss = 0
    valid_loss = 0
    for X_train, y_train in dloader_train:
        y_pred = model(X_train)
        optimizer.zero_grad() # Set the gradients to zero before calculating the new gradients for this batch, otherwise they will accumulate with the previous batch's gradients
        loss = loss_fcn(y_pred, y_train.reshape(-1,1))
        tot_loss += loss.detach()
        loss.backward()
        optimizer.step() # Update the model parameters using the calculated gradients
    
    for X_valid, y_valid in dloader_validate:
        y_pred_v = model(X_valid)
        vloss = loss_fcn(y_pred_v, y_valid.reshape(-1,1))
        valid_loss += vloss.detach()
    
    return tot_loss/len(dataset_train), valid_loss/len(dataset_validate) # Returns the average training and validation loss for this epoch

# %%
X_train = torch.vstack([dataset_train[i][0] for i in range(len(dataset_train))])
y_train = torch.vstack([dataset_train[i][1] for i in range(len(dataset_train))])
X_valid = torch.vstack([dataset_validate[i][0] for i in range(len(dataset_validate))])
y_valid = torch.vstack([dataset_validate[i][1] for i in range(len(dataset_validate))])
X_test = torch.vstack([dataset_test[i][0] for i in range(len(dataset_test))])
y_test = torch.vstack([dataset_test[i][1] for i in range(len(dataset_test))])


def plot_decision_boundary(ax, scatter_x, scatter_y):
    N = 1000
    X_grid = np.meshgrid(np.linspace(-7,7,N),np.linspace(-7,7,N))
    X_grid2 = np.array([X_grid[0].flatten(),X_grid[1].flatten()])
    preds = model(torch.tensor(X_grid2.transpose()).float()).reshape((N, N)).detach()
    ax.contourf(X_grid[0],X_grid[1], preds, cmap = plt.cm.cividis, alpha = 0.5)
    ax.scatter(scatter_x[:,0],scatter_x[:,1],c = scatter_y, cmap = plt.cm.cividis, edgecolor='black',lw = 0.5)
    ax.set_xlabel('$X_1$',fontsize = 16)
    ax.set_ylabel('$X_2$',fontsize = 16)
    ax.set_xlim(-4, 4)
    ax.set_ylim(-3.5,3.5)

# %% [markdown]
# #### Data visualization

# %%
# Run training for 25 epochs and plot the decision boundary after each epoch
import matplotlib.pyplot as plt
fig, ax = plt.subplots(5,5,figsize = (20,20))

t_loss, v_loss = [],[]
for i in range(25):
    train_loss,valid_loss = train_epoch()
    t_loss.append(train_loss)
    v_loss.append(valid_loss)
    plot_decision_boundary(ax[int(i/5), i%5], X_train, y_train)
    ax[int(i/5),i%5].set_title('Epoch {}'.format(i+1),fontsize = 20)

fig.tight_layout()

# Code for plotting validation data and test data:
# plot_decision_boundary(ax, X_valid, y_valid)
# plot_decision_boundary(ax, X_test, y_test)

# %% [markdown]
# **To see how our prediction improves as we train: plot the training and validation loss as a function of epoch**

# %%
fig, ax = plt.subplots(1,1,figsize = (8,6),dpi = 150)

ax.plot(t_loss, color='black',label='Training loss')
ax.plot(v_loss, color='#D55E00',label='Validation loss')
ax.set_xlabel('Epoch',fontsize = 16)
ax.set_ylabel('Binary cross entropy',fontsize = 16)
ax.set_title('Loss during training',fontsize = 20)
ax.tick_params(labelsize =12, which = 'both',top=True, right = True, direction='in')
ax.grid(color='xkcd:dark blue',alpha = 0.2)
ax.legend(loc='upper right',fontsize = 12)

# %% [markdown]
# #### Accuracy and ROC-AUC

# %% [markdown]
# **Accuracy:** if our output is greater than 0.5, we say it is more likely that the given point is in class 2 and so we predict class 2. In contrast, if the output is less than 0.5 then we predict class 1.

# %%
# Need to decide what class to predict, and make sure the prediction tensor is in the right shape
from sklearn.metrics import accuracy_score

train_pred = torch.Tensor([0 if x < 0.5 else 1 for x in model(X_train)]).reshape(y_train.shape)
train_accuracy = accuracy_score(y_true = y_train,
                                y_pred = train_pred)

valid_pred = torch.Tensor([0 if x < 0.5 else 1 for x in model(X_valid)]).reshape(y_valid.shape)
valid_accuracy = accuracy_score(y_true = y_valid,
                                y_pred = valid_pred)

print('Training accuracy = {:.1f}%'.format(train_accuracy*100))
print('Validation accuracy = {:.1f}%'.format(valid_accuracy*100))
# Out:
# Training accuracy = 99.4%
# Validation accuracy = 96.7%

# %%
from sklearn.metrics import roc_curve, roc_auc_score

roc_score = roc_auc_score(y_true = y_valid.detach().numpy(),
                          y_score = model(X_valid).detach().numpy())

fpr, tpr, thresholds = roc_curve(y_true = y_valid.detach().numpy(),
                                 y_score = model(X_valid).detach().numpy())

fig, ax = plt.subplots(1,1,figsize = (6, 4), dpi = 150)
ax.plot(fpr, tpr, color='#D55E00')
ax.set_xlabel('False positive rate',fontsize = 20)
ax.set_ylabel('True positive rate',fontsize = 20)
ax.set_title('ROC curve, validation data',fontsize = 24)
ax.tick_params(which='both',direction='in',top=True,right=True,labelsize = 16)
ax.grid(color='xkcd:dark blue',alpha = 0.2)

print('ROC score = {:.3f}'.format(roc_score))
# Out:
# ROC score = 0.998

# %% [markdown]
# <hr style="border:2px solid #9EC6E1">
#
# # <h1><a id="Week10" style="color:black;">Week 10: Convolutional Neural Networks</a></h1>
#
# <hr style="border:2px solid #9EC6E1">

# %% [markdown]
# When we apply a kernel of size $N \times M$:
#
# * We take all of the pixels in an $N \times M$ grid around a point in the image and performs a weighted sum, where the kernel contains the weights we use
# <br>
#
# * Then, move the kernel one pixel over and take another weighted sum (with the same weights) of the new set of pixels.
# <br>
#
# * You repeat this process for the whole image
#
# <img src='Week10_plots/conv.gif' align='center' width = 300>
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# Features of CNN:
# 1. **Translational invariance:** you can pick up individual patterns regardless of where they are in the input
# 2. **Re-use of parameters:** only have to learn the parameters in the kernel
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">
#
# Size control:
# - **Stride:** How many pixels we move our kernel across our input (risk losing information)
# - **Pooling:** separate input into pools each containing N inputs & obtain a single value for each pool & reduce the size by N
# - **Padding:** Adding extra values into the input around the edges so that the output size is the same as the input size
#
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %% [markdown]
# ## <h2><a id="pytorch10">PyTorch</a></h2>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and visualise the image
img = Image.open('dollar_image.jpg')

plt.imshow(img)
plt.axis('off')

# Convert the image to a tensor and normalise it
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms

transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])

# print(transform(img))
print(transform(img).shape)
# Out:
# torch.Size([3, 138, 300])

# %% [markdown]
# ### <h3><a id="conv layer" style="color:#5575a9; text-decoration: None">Define convolution layer</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %%
# Sobel operator takes two kenels
sobel_horizontal = torch.tensor([[-1.,0.,1.],
                                 [-2., 0., 2.],
                                 [-1., 0., 1.]]).view(1, 1, 3, 3).repeat(1, 3, 1, 1) # Replicate the kernel for each channel
sobel_vertical = torch.tensor([[-1.,0.,1.],
                                 [-2., 0., 2.],
                                 [-1., 0., 1.]]).T.view(1, 1, 3, 3).repeat(1, 3, 1, 1)

gauss_blur = 1/16 * torch.Tensor([[1, 2, 1],
                                  [2, 4, 2],
                                  [1, 2, 1]]).view(1, 1, 3, 3).repeat(1, 3, 1, 1) 

sharpen = torch.Tensor([[0, -1, 0],
                        [-1, 5, -1],
                        [0, -1, 0]]).view(1, 1, 3, 3).repeat(1, 3, 1, 1) 

ridge = torch.Tensor([[0, -1, 0],
                      [-1, 4, -1],
                      [0, -1, 0]]).view(1, 1, 3, 3).repeat(1, 3, 1, 1) 

edge = torch.Tensor([[-1, -1, -1],
                     [-1, 8, -1],
                     [-1, -1, -1]]).view(1, 1, 3, 3).repeat(1, 3, 1, 1) 

weights = torch.concat([sobel_horizontal, sobel_vertical, gauss_blur, sharpen, ridge, edge], dim = 0)

conv_layer = nn.Conv2d(in_channels = 3,
                       out_channels = 6,
                       kernel_size = 3,
                       padding = 1)

# print(conv_layer.weight)

conv_layer.weight = nn.Parameter(weights)

# %%
feature_map = conv_layer(transform(img))

print(feature_map.shape)
# Out:
# torch.Size([6, 138, 300])

# %% [markdown]
# Normalize to 0-1, define a function to go from our feature map to an image using `torchvision.utils.make_grid`

# %%
import numpy as np

def imshow(img, ax):
    '''Visualise a feature map after applying torchvision.utils.make_grid to it. 
    
    Inputs:
        img : output from torchvision.utils.make_grid
        ax : Axes object in your plot
    
    '''
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy() # Return tensor to numpy array
    ax.imshow(np.transpose(npimg, (1, 2, 0)))

fig, axs = plt.subplots(2,3, figsize = (15, 10), dpi = 100)

for i in range(6):
    imshow(torchvision.utils.make_grid(feature_map[i], normalize = True, nrow = 3), axs[int(i/3), i%3])
for ax in axs.flatten():
    ax.axis('off')

axs[0,0].set_title('Vertical edge detection',fontsize = 20)
axs[0,1].set_title('Horizontal edge detection',fontsize = 20)
axs[0,2].set_title('Gaussian blur',fontsize = 20)
axs[1,0].set_title('Sharpen',fontsize = 20)
axs[1,1].set_title('Ridge detection',fontsize = 20)
axs[1,2].set_title('Edge detection',fontsize = 20)

fig.tight_layout()

# %% [markdown]
# ### <h3><a id="padding" style="color:#5575a9; text-decoration: None">Padding</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %%
model_1 = nn.Conv2d(in_channels = 3,
                    out_channels = 1,
                    kernel_size = (3, 3),
                    stride = 1,
                    padding = 2,
                    padding_mode='zeros')

model_2 = nn.Sequential(nn.ZeroPad2d(padding = 2),
                        nn.Conv2d(in_channels = 3,
                                  out_channels = 1,
                                  kernel_size = (3, 3),
                                  stride = 1))

# %% [markdown]
# ### <h3><a id="Pooling" style="color:#5575a9; text-decoration: None">Pooling</a></h3>
# <hr style="height: 2px; border: none; background-color: #DFDFEA;">

# %%
# Fix manual seed to compare with previous models
torch.manual_seed(1)
model_3 = nn.Sequential(nn.Conv2d(in_channels = 3,
                                  out_channels = 1,
                                  kernel_size = (3, 3),
                                  stride = 1,
                                  padding = 2, 
                                  padding_mode = 'zeros'),
                        nn.MaxPool2d(kernel_size = (2, 2),
                                     stride = 2))

# print('Example array shape: {}'.format(example_arr.shape))
# print('Model 1 output shape: {}'.format(model_1(example_arr).shape))
# print('Model 2 output shape: {}'.format(model_2(example_arr).shape))
# print('Model 3 output shape: {}'.format(model_3(example_arr).shape))

# %% [markdown]
# ## <h2><a id="MNISTexample">Multiclass Classification example</a></h2>

# %%
import torchvision
import torch.nn as nn
import torch
from torchvision.datasets import FashionMNIST
from torchvision import transforms

transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])

#Define dataset
train_dataset = FashionMNIST(root='Week10_data', train=True, transform=transform, download=True)
train_daetast, validation_dataset = torch.utils.data.random_split(train_dataset, lengths = [0.8, 0.2], generator = torch.Generator().manual_seed(1))
test_dataset = FashionMNIST(root='Week10_data',train = False, transform = transform, download = True)

# Define DataLoaders
train_dloader = torch.utils.data.DataLoader(train_dataset, batch_size = 64, shuffle = True, drop_last = True)
val_dloader = torch.utils.data.DataLoader(validation_dataset, batch_size = 64, shuffle = True, drop_last = True)
test_dloader = torch.utils.data.DataLoader(test_dataset, batch_size = 4, shuffle = False, generator = torch.Generator().manual_seed(1))

# %%
import matplotlib.pyplot as plt

exmp_imgs = [train_dataset[i][0] for i in range(16)]
# Organize the images into a grid for nicer visualization
img_grid = torchvision.utils.make_grid(torch.stack(exmp_imgs, dim=0), nrow=4, normalize=True, pad_value=0.5)
img_grid = img_grid.permute(1, 2, 0)

plt.figure(figsize=(8,8))
plt.title("FashionMNIST examples")
plt.imshow(img_grid)
plt.axis('off')
plt.show()
plt.close()

# %% [markdown]
# #### Model - example with varying output channels from the first conv layer

# %%
from tqdm import tqdm

def trainModel(output_channels, loss_fcn, n_epochs):
    torch.manual_seed(1) # Fix seed for reproducibility
    
    model = nn.Sequential(nn.Conv2d(in_channels = 1,
                                    out_channels = output_channels,
                                    kernel_size = 5),
                          nn.ReLU(),
                          nn.MaxPool2d(kernel_size = 2,
                                       stride = 2),
                          nn.Flatten(start_dim = 1), 
                          nn.Linear(in_features = output_channels * 12 * 12,
                                    out_features = 10)) 
    
    optimizer = torch.optim.SGD(params = model.parameters(), lr = 0.001, momentum = 0.9)
    
    train_losses, val_losses = [], []
    for epoch in range(n_epochs):
        model.train()
        tloss, vloss = 0, 0
        true_preds, counts = 0., 0
        for X_train, y_train in tqdm(train_dloader, desc='Epoch {}, training'.format(epoch+1)):
            optimizer.zero_grad()
            pred = model(X_train)
            loss = loss_fcn(pred, y_train)
            tloss += loss.item()
            loss.backward()
            optimizer.step()
            true_preds+= (pred.argmax(dim = -1)==y_train).sum()
            counts += len(y_train)
        train_acc = true_preds/counts
            
        model.eval()
        with torch.no_grad():
            vtrue_preds, vcount = 0., 0
            for X_valid, y_valid in tqdm(val_dloader, desc='Epoch {}, validation'.format(epoch+1)):
                pred = model(X_valid)
                loss = loss_fcn(pred, y_valid)
                vloss += loss.item()
                vtrue_preds += (pred.argmax(dim = -1)==y_valid).sum()
                vcount += len(y_valid)
        val_acc = vtrue_preds/vcount
        
        print(f"[Epoch {epoch+1:2d}] Training accuracy: {train_acc*100.0:05.2f}%, Validation accuracy: {val_acc*100.0:05.2f}%")
        train_losses.append(tloss)
        val_losses.append(vloss)
        
    return model, train_losses, val_losses, optimizer

# %% [markdown]
# **Early Stopping:** If our validation loss stops improving but our training loss continues to improve - indication of overfitting to the training dataset - stop training if it has not improved for a set number of epochs

# %%
#Example code

best_val_loss = float('inf')
best_val_epoch = 0
for i in range(20):
    val_loss = train_epoch(model, optimizer, i)
    if val_loss[1] < best_val_loss:
        best_val_loss = val_loss[1]
        best_val_epoch = i
    if(i-best_val_epoch > 2):  # Early stopping if no improvement in 3 epochs
        print('Early stopping at epoch {}'.format(i))
        break
# Out:
# 100%|██████████| 750/750 [00:17<00:00, 43.09it/s]
# [Epoch  1] Training accuracy: 86.44%, Validation accuracy: 86.09%
# 100%|██████████| 750/750 [00:17<00:00, 43.30it/s]
# [Epoch  2] Training accuracy: 86.78%, Validation accuracy: 86.14%
# 100%|██████████| 750/750 [00:17<00:00, 43.49it/s]
# [Epoch  3] Training accuracy: 86.93%, Validation accuracy: 84.73%
# 100%|██████████| 750/750 [00:17<00:00, 43.71it/s]
# [Epoch  4] Training accuracy: 87.12%, Validation accuracy: 86.21%
# Early stopping at epoch 3

# %% [markdown]
# #### Training

# %%
output_channels = [2, 5, 10, 20]
output_channels_models, output_channels_optimizers, output_channels_train_losses, output_channels_val_losses = {},{},{},{}


for output_chann in output_channels:
    model, tlosses, vlosses, optimizer = trainModel(output_chann, nn.CrossEntropyLoss(reduction='sum'), n_epochs = 2)
    output_channels_train_losses[output_chann] = tlosses
    output_channels_val_losses[output_chann] = vlosses
    output_channels_models[output_chann] = model
    output_channels_optimizers[output_chann] = optimizer
    print('Finished training model with {} output channels in first convolutional layer'.format(output_chann))
# Out:
# ...
# Epoch 1, validation: 100%|██████████| 187/187 [00:04<00:00, 46.38it/s]
# [Epoch  1] Training accuracy: 76.74%, Validation accuracy: 78.74%
# ...
# Epoch 2, validation: 100%|██████████| 187/187 [00:03<00:00, 48.85it/s]
# [Epoch  2] Training accuracy: 81.41%, Validation accuracy: 80.05%
# Finished training model with 2 output channels in first convolutional layer
# ...
# Epoch 1, validation: 100%|██████████| 187/187 [00:03<00:00, 47.52it/s]
# [Epoch  1] Training accuracy: 81.09%, Validation accuracy: 84.47%
# ...
# Epoch 2, validation: 100%|██████████| 187/187 [00:03<00:00, 48.35it/s]
# [Epoch  2] Training accuracy: 85.23%, Validation accuracy: 84.51%
# Finished training model with 5 output channels in first convolutional layer
# ...
# Epoch 1, validation: 100%|██████████| 187/187 [00:04<00:00, 46.53it/s]
# [Epoch  1] Training accuracy: 82.58%, Validation accuracy: 84.48%
# ...
# Epoch 2, validation: 100%|██████████| 187/187 [00:03<00:00, 46.82it/s]
# ...

# %% [markdown]
# #### Output

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

def evaluateModel(model):
    y_t, y_preds = [], []
    total_correct, total_count = 0., 0
    model.eval()
    with torch.no_grad():
        for X_test, y_test in test_dloader:
            y_t.append(y_test)
            y_preds.append(model(X_test))
    y_t = torch.concat(y_t)
    y_preds = torch.concat(y_preds)
    probs = nn.functional.softmax(y_preds, dim = -1)
    pred_labels = y_preds.argmax(dim = -1)
    roc_aucs = roc_auc_score(y_t.detach().numpy(), probs.detach().numpy(), multi_class='ovr', average=None)
    accs = accuracy_score(y_t.detach().numpy(), pred_labels.detach().numpy())
    accs_per_class = [accuracy_score(y_t[y_t==i].detach().numpy(), pred_labels[y_t==i].detach().numpy()) for i in range(10)]
    
        
    return y_t, y_preds, probs, pred_labels, roc_aucs, accs, accs_per_class

# %%
import matplotlib.pyplot as plt
import numpy as np


def imshow(img, ax):
    '''Visualise a feature map after applying torchvision.utils.make_grid to it. 
    
    Inputs:
        img : output from torchvision.utils.make_grid
        ax : Axes object in your plot
    
    '''
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy() # Return tensor to numpy array
    ax.imshow(np.transpose(npimg, (1, 2, 0)))

test_iter = iter(test_dloader)
images, labels = next(test_iter)

fig, ax = plt.subplots(1,1)
plt.axis('off')
imshow(torchvision.utils.make_grid(images),ax)

print(labels)

output_channels_models[20].eval()

outputs = output_channels_models[20](images)

print(outputs)
#For each sample, we output a vector of length 10, where each value corresponds to the "energy" for one of the classes. 
# The higher the etorch.argmax(outputs, dim = -1)nergy, the more the network thinks the sample belongs to that class.
torch.argmax(outputs, dim = -1)
# Out:
# tensor([9, 2, 1, 1])
# tensor([[ -2.1690,  -5.2425,  -1.1058,  -0.5512,  -2.7501,   5.0687,  -2.8483,
#            0.8737,  -0.1383,   9.0262],
#         [  8.8479,  -2.5024,  20.2527,   0.0397,   4.4696, -11.0051,   2.5593,
#           -9.2315,  -2.6729,  -9.9548],
#         [ -0.6339,  15.0445,  -3.0247,   0.0665,   1.6433,  -3.2065,  -3.4999,
#           -1.6029,  -0.7535,  -4.4239],
#         [ -1.9354,  14.8248,  -3.2745,   2.3130,   0.4630,  -2.7163,  -3.1939,
#           -1.9678,  -1.3130,  -3.7172]], grad_fn=<AddmmBackward0>)
# tensor([9, 2, 1, 1])

# %%
output_channels_roc_aucs, output_channels_labels, output_channels_probs, output_channels_accs = {}, {}, {}, {}
output_channels_total_accs = {}
for output_chann in output_channels:
    y_test, y_preds, probs, pred_labels, roc_aucs, accs, accs_per_class = evaluateModel(output_channels_models[output_chann])
    output_channels_roc_aucs[output_chann] = roc_aucs
    output_channels_labels[output_chann] = pred_labels
    output_channels_probs[output_chann] = probs
    output_channels_total_accs[output_chann] = accs
    output_channels_accs[output_chann] = accs_per_class

classes = ('t-shirt/top', 'trouser', 'pullover', 'dress',
           'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot')

for output_chann in output_channels:
    print('For model with {} output channels in first convolutional layer:'.format(output_chann))
    print('Total classification accuracy = {:.2f}%'.format(output_channels_total_accs[output_chann]*100)) #accs

    for i in range(10):
        print('For class {}:'.format(classes[i]))
        print('    Classification accuracy = {:.2f}%'.format(100*output_channels_accs[output_chann][i])) #accs_per_class
        print('    ROC-AUC score = {:.5f}'.format(output_channels_roc_aucs[output_chann][i])) #roc_aucs
        print('')
# Out:
# For model with 2 output channels in first convolutional layer:
# Total classification accuracy = 79.87%
# For class t-shirt/top:
#     Classification accuracy = 88.50%
#     ROC-AUC score = 0.96815
#
# For class trouser:
#     Classification accuracy = 95.40%
#     ROC-AUC score = 0.99527
#
# For class pullover:
#     Classification accuracy = 59.60%
#     ROC-AUC score = 0.95465
#
# For class dress:
#     Classification accuracy = 78.60%
#     ROC-AUC score = 0.98314
#
# For class coat:
#     Classification accuracy = 69.30%
#     ROC-AUC score = 0.96510
#
# For class sandal:
#     Classification accuracy = 88.60%
#     ROC-AUC score = 0.99373
#
# For class shirt:
#     Classification accuracy = 47.30%
#     ROC-AUC score = 0.90126
#
# For class sneaker:
#     Classification accuracy = 88.20%
#     ROC-AUC score = 0.99373
#
# For class bag:
#     Classification accuracy = 94.90%
#     ROC-AUC score = 0.99034
#
# For class ankle boot:
#     Classification accuracy = 88.30%
# ...

# %% [markdown]
# Put all of the classification accuracies and ROC-AUC scores into a pandas DataFrame:

# %%
import pandas as pd

# Define the index for our DataFrame manually
index = pd.MultiIndex.from_tuples([(output_chann, metric) 
                                   for output_chann in output_channels 
                                   for metric in ['Accuracy','ROC-AUC score']], 
                                  names = ['Number of output channels', 'Metric'])

results_df = pd.DataFrame(index = index, columns = ['Total'] + [c for c in classes])

for output_chann in output_channels:
    results_df.loc[(output_chann, 'Accuracy')] = [output_channels_total_accs[output_chann]] + output_channels_accs[output_chann]
    results_df.loc[(output_chann, 'ROC-AUC score')] = [np.nan] + list(output_channels_roc_aucs[output_chann])

results_df
# Out:
#                                           Total t-shirt/top   trouser  \
# Number of output channels Metric
# 2                         Accuracy       0.7987       0.885     0.954
#                           ROC-AUC score     NaN    0.968146  0.995271
# 5                         Accuracy       0.8357       0.581      0.95
#                           ROC-AUC score     NaN    0.977161  0.998123
# 10                        Accuracy       0.8578       0.802     0.968
#                           ROC-AUC score     NaN    0.981905  0.998853
# 20                        Accuracy       0.8574       0.843     0.965
#                           ROC-AUC score     NaN    0.981292  0.998938
#
#                                          pullover     dress      coat  \
# Number of output channels Metric
# 2                         Accuracy          0.596     0.786     0.693
#                           ROC-AUC score  0.954652  0.983144  0.965097
# ...

# %% [markdown]
# **Plot the confusion matrix**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig, ax = plt.subplots(1,1, figsize = (6,6),dpi = 150)

cm = confusion_matrix(y_test, output_channels_labels[20]) #(y_test, pred_labels)
ConfusionMatrixDisplay(cm, display_labels = classes).plot(cmap = plt.cm.cividis, ax = ax, xticks_rotation='vertical')

# %% [markdown]
# Convert the output of our CNN to a normalised probability per class and plot ROC curves and calculate ROC-AUC scores for each class

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from matplotlib.ticker import MultipleLocator

fig, ax = plt.subplots(2, 5, figsize = (15, 6), dpi = 150)
for i in range(5):
    for j in range(2):
        # Find probability of predicting specific class
        specific_prob = output_channels_probs[20][:,j + 2*i].detach().numpy() #specific_prob = probs2.detach().numpy()[:,j + 2*i]
        # pos_label argument lets us specify the "positive" class
        fpr, tpr, _ = roc_curve(y_test.detach().numpy(), specific_prob, pos_label = j + 2*i)
        ax[j,i].plot(fpr, tpr, color='#D55E00')
        ax[j,i].set_xlabel('False positive rate',fontsize = 16)
        ax[j,i].set_ylabel('True positive rate', fontsize = 16)
        ax[j,i].xaxis.set_minor_locator(MultipleLocator(0.04))
        ax[j,i].yaxis.set_minor_locator(MultipleLocator(0.04))
        ax[j,i].tick_params(labelsize = 12, which='both',direction='in', top=True, right=True)
        ax[j,i].set_title('ROC curve for\n{} class'.format(classes[j+2*i]), fontsize = 20)
        ax[j,i].grid(color='xkcd:dark blue',alpha = 0.2)
        
fig.tight_layout()

# %%
# Save model

# torch.save(output_channels_models[20],'best_fashionmnist_net.pt')
